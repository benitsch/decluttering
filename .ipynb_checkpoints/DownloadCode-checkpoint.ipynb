# %%
import urllib.request
import pandas as pd
import os

# %%
#downloadCode from given ulr and write to outPath
def downloadCode(ulr,outPath):
    response = urllib.request.urlopen(ulr)  
    html = response.read().decode('utf-8')
    i = 0
    if os.path.isfile(outPath):
        print("file ",outPath," existed")
        return
    with open(outPath,"w") as outfile:
        outfile.write(html)
#     print(html)

# %%
# Store code to data dir. 
dataPath = "data/"
if not os.path.isdir(dataPath):
    print("build data dir :" ,dataPath)
    os.mkdir(dataPath)

path = "assets/declutter-gold_DevelopmentSet.csv"
dataframe = pd.read_csv(path, na_filter = False)
for name in dataframe["path_to_file"]:
    name = name.replace("https://github.com/","https://raw.githubusercontent.com/")
    name = name.replace("blob/","",1)
    outPath = name.split("/")[-1]
    print(dataPath+outPath)
    downloadCode(name,dataPath+outPath)
# Out:
# data/TextInputControlBehavior.java
# file  data/TextInputControlBehavior.java  existed
# data/CellFactory.java
# data/TemporalAccessorPicker.java
# data/JabRefFrame.java
# data/IconTheme.java
# data/ExternalFileTypes.java
# data/BibtexKeyPatternPanel.java
# data/ApplicationInsightsLogEvent.java
# data/JabRefGUI.java
# data/JabRefGUI.java
# file  data/JabRefGUI.java  existed
# data/ExportToClipboardAction.java
# data/DefaultFileUpdateMonitor.java
# data/GroupDialog.java
# data/BindingsHelper.java
# data/BackgroundTask.java
# data/GroupTreeViewModel.java
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/EntryChangeViewModel.java
# data/AutoCompleteFirstNameMode.java
# data/FileDialogConfiguration.java
# data/PreferencesTab.java
# data/OOBibBase.java
# data/SaveDatabaseAction.java
# data/MergeEntries.java
# data/SimpleEditor.java
# data/PreviewTabViewModel.java
# data/BindingsHelper.java
# file  data/BindingsHelper.java  existed
# data/TooltipTextUtil.java
# data/ErrorConsoleViewModel.java
# data/CopyBibTeXKeyAndLinkAction.java
# data/MergeEntries.java
# file  data/MergeEntries.java  existed
# data/BibEntrySuggestionProvider.java
# data/IconTheme.java
# file  data/IconTheme.java  existed
# data/ManageJournalAbbreviationsViewModel.java
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/OptionalObjectProperty.java
# data/OldDatabaseCommandWrapper.java
# data/JabRefGUI.java
# file  data/JabRefGUI.java  existed
# data/FieldsEditorTab.java
# data/DuplicateSearch.java
# data/ErrorConsoleViewModel.java
# file  data/ErrorConsoleViewModel.java  existed
# data/KeyBindingViewModel.java
# data/UndoablePreambleChange.java
# data/DocumentViewerControl.java
# data/IconTheme.java
# file  data/IconTheme.java  existed
# data/SearchDescribers.java
# data/ReplaceStringViewModel.java
# data/JabRefDesktop.java
# data/KeyBindingRepository.java
# data/EntryEditor.java
# data/MainTable.java
# data/AppendDatabaseAction.java
# data/GroupTreeNodeViewModel.java
# data/OpenOfficePanel.java
# data/GroupDialog.java
# file  data/GroupDialog.java  existed
# data/ErrorConsoleViewModel.java
# file  data/ErrorConsoleViewModel.java  existed
# data/EntryEditorTab.java
# data/CitationsDisplay.java
# data/ExternalFileTypes.java
# file  data/ExternalFileTypes.java  existed
# data/CustomLocalDragboard.java
# data/ParseTexResultViewModel.java
# data/FromAuxDialog.java
# data/ParserResultWarningDialog.java
# data/MappedList.java
# data/GroupTreeView.java
# data/URLUtil.java
# data/ExportCommand.java
# data/MergeEntries.java
# file  data/MergeEntries.java  existed
# data/CustomLocalDragboard.java
# file  data/CustomLocalDragboard.java  existed
# data/ImportEntriesViewModel.java
# data/ImportEntriesViewModel.java
# file  data/ImportEntriesViewModel.java  existed
# data/ImportEntriesViewModel.java
# file  data/ImportEntriesViewModel.java  existed
# data/PdfDocumentPageViewModel.java
# data/LinkedFilesEditDialogViewModel.java
# data/ExportCommand.java
# file  data/ExportCommand.java  existed
# data/SaveDatabaseAction.java
# file  data/SaveDatabaseAction.java  existed
# data/JabRefMain.java
# data/ActionFactory.java
# data/DiffHighlightingTextPane.java
# data/ManageJournalAbbreviationsViewModel.java
# file  data/ManageJournalAbbreviationsViewModel.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/GrammarBasedSearchRuleDescriber.java
# data/GenerateBibtexKeyAction.java
# data/GUIPostOpenAction.java
# data/UnlinkedFilesCrawler.java
# data/FindFullTextAction.java
# data/UrlEditor.java
# data/SuggestionProvider.java
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/ImportAction.java
# data/SaveAllAction.java
# data/ManageJournalAbbreviationsViewModel.java
# file  data/ManageJournalAbbreviationsViewModel.java  existed
# data/AppendDatabaseAction.java
# file  data/AppendDatabaseAction.java  existed
# data/VersionWorker.java
# data/EntryDeleteChangeViewModel.java
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/PreferencesDialogViewModel.java
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/IconTheme.java
# file  data/IconTheme.java  existed
# data/BibtexKeyPatternPanel.java
# file  data/BibtexKeyPatternPanel.java  existed
# data/SuggestionProvider.java
# file  data/SuggestionProvider.java  existed
# data/DirectoryDialogConfiguration.java
# data/IconTheme.java
# file  data/IconTheme.java  existed
# data/CitationStyleToClipboardWorker.java
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/TextInputControlBehavior.java
# file  data/TextInputControlBehavior.java  existed
# data/BibtexKeyPatternPanel.java
# file  data/BibtexKeyPatternPanel.java  existed
# data/SearchDisplayMode.java
# data/GlobalSearchBar.java
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/CleanupAction.java
# data/ExternalFileTypes.java
# file  data/ExternalFileTypes.java  existed
# data/SourceTab.java
# data/UndoablePreambleChange.java
# file  data/UndoablePreambleChange.java  existed
# data/ChangeScanner.java
# data/DocumentViewerControl.java
# file  data/DocumentViewerControl.java  existed
# data/JabRefMain.java
# file  data/JabRefMain.java  existed
# data/CustomExternalFileType.java
# data/JabRefGUI.java
# file  data/JabRefGUI.java  existed
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/BibtexKeyPatternPanel.java
# file  data/BibtexKeyPatternPanel.java  existed
# data/Bootstrap.java
# data/CaseChangeMenu.java
# data/ImportAction.java
# file  data/ImportAction.java  existed
# data/ViewModelListCellFactory.java
# data/GroupNodeViewModel.java
# data/ImportAction.java
# file  data/ImportAction.java  existed
# data/WaitForSaveFinishedDialog.java
# data/PreviewTabViewModel.java
# file  data/PreviewTabViewModel.java  existed
# data/JabRefMain.java
# file  data/JabRefMain.java  existed
# data/PersistenceVisualStateTable.java
# data/LibraryPropertiesDialogViewModel.java
# data/JabRefDesktop.java
# file  data/JabRefDesktop.java  existed
# data/ThemeLoader.java
# data/EntryEditor.java
# file  data/EntryEditor.java  existed
# data/ActionFactory.java
# file  data/ActionFactory.java  existed
# data/ManageJournalAbbreviationsView.java
# data/URLUtil.java
# file  data/URLUtil.java  existed
# data/GroupDialog.java
# file  data/GroupDialog.java  existed
# data/GroupDialog.java
# file  data/GroupDialog.java  existed
# data/GroupTreeViewModel.java
# file  data/GroupTreeViewModel.java  existed
# data/DocumentViewerControl.java
# file  data/DocumentViewerControl.java  existed
# data/MergeEntries.java
# file  data/MergeEntries.java  existed
# data/PreferencesTab.java
# file  data/PreferencesTab.java  existed
# data/PushToApplication.java
# data/AppendDatabaseAction.java
# file  data/AppendDatabaseAction.java  existed
# data/MassSetFieldsAction.java
# data/FindUnlinkedFilesDialog.java
# data/PreviewPanel.java
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/ViewModelTableRowFactory.java
# data/JabRefDesktop.java
# file  data/JabRefDesktop.java  existed
# data/GroupChangeViewModel.java
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/GlobalSearchBar.java
# file  data/GlobalSearchBar.java  existed
# data/MapBasedEditorViewModel.java
# data/EditorTextArea.java
# data/PersonNameSuggestionProvider.java
# data/PreviewTabViewModel.java
# file  data/PreviewTabViewModel.java  existed
# data/PreferencesDialogViewModel.java
# file  data/PreferencesDialogViewModel.java  existed
# data/EntryEditor.java
# file  data/EntryEditor.java  existed
# data/TableColumnsTabViewModel.java
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/ManageJournalAbbreviationsViewModel.java
# file  data/ManageJournalAbbreviationsViewModel.java  existed
# data/ParserResultWarningDialog.java
# file  data/ParserResultWarningDialog.java  existed
# data/JabRefAction.java
# data/ExternalTabViewModel.java
# data/FileTabViewModel.java
# data/IconTheme.java
# file  data/IconTheme.java  existed
# data/Bootstrap.java
# file  data/Bootstrap.java  existed
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/IconTheme.java
# file  data/IconTheme.java  existed
# data/DocumentViewerControl.java
# file  data/DocumentViewerControl.java  existed
# data/AbstractPushToApplication.java
# data/UndoableAddOrRemoveGroup.java
# data/GroupNodeViewModel.java
# file  data/GroupNodeViewModel.java  existed
# data/Bootstrap.java
# file  data/Bootstrap.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/IconTheme.java
# file  data/IconTheme.java  existed
# data/SmartConstrainedResizePolicy.java
# data/MainTableColumnFactory.java
# data/SuggestionProvider.java
# file  data/SuggestionProvider.java  existed
# data/OpenOfficePanel.java
# file  data/OpenOfficePanel.java  existed
# data/LibraryPropertiesDialogView.java
# data/PreviewPanel.java
# file  data/PreviewPanel.java  existed
# data/DocumentPageViewModel.java
# data/ConversionMenu.java
# data/GroupTreeViewModel.java
# file  data/GroupTreeViewModel.java  existed
# data/LinkedFileViewModel.java
# data/AuxParserResultViewModel.java
# data/ManageJournalAbbreviationsViewModel.java
# file  data/ManageJournalAbbreviationsViewModel.java  existed
# data/BackgroundTask.java
# file  data/BackgroundTask.java  existed
# data/SuggestionProvider.java
# file  data/SuggestionProvider.java  existed
# data/URLUtil.java
# file  data/URLUtil.java  existed
# data/SidePaneManager.java
# data/UndoableFieldChange.java
# data/AbstractPushToApplication.java
# file  data/AbstractPushToApplication.java  existed
# data/SourceTab.java
# file  data/SourceTab.java  existed
# data/OldCommandWrapper.java
# data/EditorMenus.java
# data/MainTableColumnFactory.java
# file  data/MainTableColumnFactory.java  existed
# data/AbstractPushToApplication.java
# file  data/AbstractPushToApplication.java  existed
# data/JabRefExecutorService.java
# data/ExternalFileTypes.java
# file  data/ExternalFileTypes.java  existed
# data/UndoableAbbreviator.java
# data/Bootstrap.java
# file  data/Bootstrap.java  existed
# data/UndoableFieldChange.java
# file  data/UndoableFieldChange.java  existed
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/BibtexKeyPatternPanel.java
# file  data/BibtexKeyPatternPanel.java  existed
# data/OptionalObjectProperty.java
# file  data/OptionalObjectProperty.java  existed
# data/TextInputControlBehavior.java
# file  data/TextInputControlBehavior.java  existed
# data/IconTheme.java
# file  data/IconTheme.java  existed
# data/JabRefDesktop.java
# file  data/JabRefDesktop.java  existed
# data/JabRefExecutorService.java
# file  data/JabRefExecutorService.java  existed
# data/JabRefMessageHandler.java
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/PushToApplicationAction.java
# data/NormalTableColumn.java
# data/DefaultDesktop.java
# data/KeyBindingRepository.java
# file  data/KeyBindingRepository.java  existed
# data/PersistenceVisualStateTable.java
# file  data/PersistenceVisualStateTable.java  existed
# data/GroupTreeViewModel.java
# file  data/GroupTreeViewModel.java  existed
# data/ManageJournalAbbreviationsViewModel.java
# file  data/ManageJournalAbbreviationsViewModel.java  existed
# data/JabRefGUI.java
# file  data/JabRefGUI.java  existed
# data/DefaultTaskExecutor.java
# data/JabRefMain.java
# file  data/JabRefMain.java  existed
# data/Bootstrap.java
# file  data/Bootstrap.java  existed
# data/SpecialFieldDatabaseChangeListener.java
# data/LinkedFileViewModel.java
# file  data/LinkedFileViewModel.java  existed
# data/EntryEditor.java
# file  data/EntryEditor.java  existed
# data/Linux.java
# data/PreferencesDialogViewModel.java
# file  data/PreferencesDialogViewModel.java  existed
# data/CustomExternalFileType.java
# file  data/CustomExternalFileType.java  existed
# data/MergeEntriesDialog.java
# data/GeneralTabViewModel.java
# data/UiThreadObservableList.java
# data/JabRefExecutorService.java
# file  data/JabRefExecutorService.java  existed
# data/ManageJournalAbbreviationsViewModel.java
# file  data/ManageJournalAbbreviationsViewModel.java  existed
# data/ManageJournalAbbreviationsViewModel.java
# file  data/ManageJournalAbbreviationsViewModel.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/BindingsHelper.java
# file  data/BindingsHelper.java  existed
# data/JabRefExecutorService.java
# file  data/JabRefExecutorService.java  existed
# data/ImportHandler.java
# data/UndoableInsertString.java
# data/ExternalFileTypes.java
# file  data/ExternalFileTypes.java  existed
# data/PreferencesDialogViewModel.java
# file  data/PreferencesDialogViewModel.java  existed
# data/EntryEditor.java
# file  data/EntryEditor.java  existed
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/ActionFactory.java
# file  data/ActionFactory.java  existed
# data/FetchAndMergeEntry.java
# data/AppendDatabaseAction.java
# file  data/AppendDatabaseAction.java  existed
# data/WebSearchPane.java
# data/ViewModelTableRowFactory.java
# file  data/ViewModelTableRowFactory.java  existed
# data/DefaultTaskExecutor.java
# file  data/DefaultTaskExecutor.java  existed
# data/RequiredFieldsTab.java
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/ManageKeywordsViewModel.java
# data/DefaultTaskExecutor.java
# file  data/DefaultTaskExecutor.java  existed
# data/BaseDialog.java
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/ExternalFileTypes.java
# file  data/ExternalFileTypes.java  existed
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/UndoableInsertString.java
# file  data/UndoableInsertString.java  existed
# data/DetectOpenOfficeInstallation.java
# data/DocumentViewerControl.java
# file  data/DocumentViewerControl.java  existed
# data/DocumentViewerControl.java
# file  data/DocumentViewerControl.java  existed
# data/MergeEntriesAction.java
# data/ManageJournalAbbreviationsView.java
# file  data/ManageJournalAbbreviationsView.java  existed
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/UndoableChangeType.java
# data/FileTabViewModel.java
# file  data/FileTabViewModel.java  existed
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/BibtexKeyPatternPanel.java
# file  data/BibtexKeyPatternPanel.java  existed
# data/GroupNodeViewModel.java
# file  data/GroupNodeViewModel.java  existed
# data/SendAsEMailAction.java
# data/OpenDatabaseAction.java
# data/RelatedArticlesTab.java
# data/ExporterViewModel.java
# data/UndoableAddOrRemoveGroup.java
# file  data/UndoableAddOrRemoveGroup.java  existed
# data/CustomExternalFileType.java
# file  data/CustomExternalFileType.java  existed
# data/ApplicationInsightsLogEvent.java
# file  data/ApplicationInsightsLogEvent.java  existed
# data/EditExternalFileTypeViewModel.java
# data/FindUnlinkedFilesDialog.java
# file  data/FindUnlinkedFilesDialog.java  existed
# data/IconTheme.java
# file  data/IconTheme.java  existed
# data/KeyBinding.java
# data/CopyDoiUrlAction.java
# data/EntryEditor.java
# file  data/EntryEditor.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/TaskExecutor.java
# data/EntryEditor.java
# file  data/EntryEditor.java  existed
# data/CleanupAction.java
# file  data/CleanupAction.java  existed
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/ExternalFileTypes.java
# file  data/ExternalFileTypes.java  existed
# data/EntryEditorTab.java
# file  data/EntryEditorTab.java  existed
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/LinkedFileViewModel.java
# file  data/LinkedFileViewModel.java  existed
# data/GroupTreeViewModel.java
# file  data/GroupTreeViewModel.java  existed
# data/DefaultFileUpdateMonitor.java
# file  data/DefaultFileUpdateMonitor.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/GroupTreeView.java
# file  data/GroupTreeView.java  existed
# data/TextFlowLimited.java
# data/ChangeScanner.java
# file  data/ChangeScanner.java  existed
# data/GroupChangeViewModel.java
# file  data/GroupChangeViewModel.java  existed
# data/CustomExternalFileType.java
# file  data/CustomExternalFileType.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/ImportEntriesViewModel.java
# file  data/ImportEntriesViewModel.java  existed
# data/SpecialFieldAction.java
# data/UndoableAddOrRemoveGroup.java
# file  data/UndoableAddOrRemoveGroup.java  existed
# data/CitationStyleToClipboardWorker.java
# file  data/CitationStyleToClipboardWorker.java  existed
# data/MainTableColumnFactory.java
# file  data/MainTableColumnFactory.java  existed
# data/JabRefMain.java
# file  data/JabRefMain.java  existed
# data/GlobalSearchBar.java
# file  data/GlobalSearchBar.java  existed
# data/JabRefGUI.java
# file  data/JabRefGUI.java  existed
# data/ZipFileChooser.java
# data/GroupTreeView.java
# file  data/GroupTreeView.java  existed
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/IconTheme.java
# file  data/IconTheme.java  existed
# data/MainTable.java
# file  data/MainTable.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/ImportCustomizationDialogViewModel.java
# data/MainTable.java
# file  data/MainTable.java  existed
# data/TextInputControlBehavior.java
# file  data/TextInputControlBehavior.java  existed
# data/JabRefDesktop.java
# file  data/JabRefDesktop.java  existed
# data/GUIPostOpenAction.java
# file  data/GUIPostOpenAction.java  existed
# data/BibtexKeyPatternPrefTab.java
# data/ApplicationInsightsLogEvent.java
# file  data/ApplicationInsightsLogEvent.java  existed
# data/Bootstrap.java
# file  data/Bootstrap.java  existed
# data/GroupModeViewModel.java
# data/JabRefGUI.java
# file  data/JabRefGUI.java  existed
# data/SuggestionProvider.java
# file  data/SuggestionProvider.java  existed
# data/VersionWorker.java
# file  data/VersionWorker.java  existed
# data/VersionWorker.java
# file  data/VersionWorker.java  existed
# data/IconTheme.java
# file  data/IconTheme.java  existed
# data/URLUtil.java
# file  data/URLUtil.java  existed
# data/ManageKeywordsViewModel.java
# file  data/ManageKeywordsViewModel.java  existed
# data/IconTheme.java
# file  data/IconTheme.java  existed
# data/Bootstrap.java
# file  data/Bootstrap.java  existed
# data/IconTheme.java
# file  data/IconTheme.java  existed
# data/GroupTreeView.java
# file  data/GroupTreeView.java  existed
# data/DatabaseChangeMonitor.java
# data/MassSetFieldsDialog.java
# data/ActionFactory.java
# file  data/ActionFactory.java  existed
# data/LibraryPropertiesDialogView.java
# file  data/LibraryPropertiesDialogView.java  existed
# data/JabRefGUI.java
# file  data/JabRefGUI.java  existed
# data/GroupNodeViewModel.java
# file  data/GroupNodeViewModel.java  existed
# data/StringChangeViewModel.java
# data/RelatedArticlesTab.java
# file  data/RelatedArticlesTab.java  existed
# data/MergeEntries.java
# file  data/MergeEntries.java  existed
# data/FindUnlinkedFilesDialog.java
# file  data/FindUnlinkedFilesDialog.java  existed
# data/EntryEditor.java
# file  data/EntryEditor.java  existed
# data/JabRefIconView.java
# data/IconTheme.java
# file  data/IconTheme.java  existed
# data/UndoableAddOrRemoveGroup.java
# file  data/UndoableAddOrRemoveGroup.java  existed
# data/VersionWorker.java
# file  data/VersionWorker.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/JabRefAction.java
# file  data/JabRefAction.java  existed
# data/SaveDatabaseAction.java
# file  data/SaveDatabaseAction.java  existed
# data/EditorMenus.java
# file  data/EditorMenus.java  existed
# data/MergeEntries.java
# file  data/MergeEntries.java  existed
# data/PreferenceTabViewModel.java
# data/AutoCompletionTextInputBinding.java
# data/DateEditorViewModel.java
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/PdfDocumentPageViewModel.java
# file  data/PdfDocumentPageViewModel.java  existed
# data/DocumentViewerView.java
# data/AbstractPushToApplication.java
# file  data/AbstractPushToApplication.java  existed
# data/ActionFactory.java
# file  data/ActionFactory.java  existed
# data/NormalTableColumn.java
# file  data/NormalTableColumn.java  existed
# data/UndoableAddOrRemoveGroup.java
# file  data/UndoableAddOrRemoveGroup.java  existed
# data/AutoCompletionTextInputBinding.java
# file  data/AutoCompletionTextInputBinding.java  existed
# data/BindingsHelper.java
# file  data/BindingsHelper.java  existed
# data/ExternalFileTypes.java
# file  data/ExternalFileTypes.java  existed
# data/GroupTreeView.java
# file  data/GroupTreeView.java  existed
# data/GenerateBibtexKeyAction.java
# file  data/GenerateBibtexKeyAction.java  existed
# data/JabRefMain.java
# file  data/JabRefMain.java  existed
# data/JabRefMain.java
# file  data/JabRefMain.java  existed
# data/EntryEditorTabList.java
# data/AppendDatabaseAction.java
# file  data/AppendDatabaseAction.java  existed
# data/FileDialogConfiguration.java
# file  data/FileDialogConfiguration.java  existed
# data/URLUtil.java
# file  data/URLUtil.java  existed
# data/AbbreviateAction.java
# data/GroupTreeViewModel.java
# file  data/GroupTreeViewModel.java  existed
# data/FileHistoryMenu.java
# data/CreateModifyExporterDialogViewModel.java
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/IconTheme.java
# file  data/IconTheme.java  existed
# data/SmartConstrainedResizePolicy.java
# file  data/SmartConstrainedResizePolicy.java  existed
# data/LinkedEntriesEditorViewModel.java
# data/CustomLocalDragboard.java
# file  data/CustomLocalDragboard.java  existed
# data/OldCommandWrapperForActiveDatabase.java
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/LinkedFileViewModel.java
# file  data/LinkedFileViewModel.java  existed
# data/ChangeScanner.java
# file  data/ChangeScanner.java  existed
# data/AutoCompletionTextInputBinding.java
# file  data/AutoCompletionTextInputBinding.java  existed
# data/LinkedFilesEditorViewModel.java
# data/SuggestionProvider.java
# file  data/SuggestionProvider.java  existed
# data/ImportEntriesViewModel.java
# file  data/ImportEntriesViewModel.java  existed
# data/MainTable.java
# file  data/MainTable.java  existed
# data/UpdateTimestampListener.java
# data/SidePaneManager.java
# file  data/SidePaneManager.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/CurrentThreadTaskExecutor.java
# data/JabRefDesktop.java
# file  data/JabRefDesktop.java  existed
# data/DocumentViewerControl.java
# file  data/DocumentViewerControl.java  existed
# data/MassSetFieldsDialog.java
# file  data/MassSetFieldsDialog.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/PreviewViewer.java
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/TemporalAccessorPicker.java
# file  data/TemporalAccessorPicker.java  existed
# data/PdfDocumentViewModel.java
# data/ExternalFileTypes.java
# file  data/ExternalFileTypes.java  existed
# data/Bootstrap.java
# file  data/Bootstrap.java  existed
# data/WriteXMPAction.java
# data/PreferencesTab.java
# file  data/PreferencesTab.java  existed
# data/JabRefMain.java
# file  data/JabRefMain.java  existed
# data/ValueTableCellFactory.java
# data/BibtexKeyPatternPrefTab.java
# file  data/BibtexKeyPatternPrefTab.java  existed
# data/UndoableModifySubtree.java
# data/MappedList.java
# file  data/MappedList.java  existed
# data/EntryEditor.java
# file  data/EntryEditor.java  existed
# data/FieldFormatterCleanupsPanel.java
# data/MainTable.java
# file  data/MainTable.java  existed
# data/GroupTreeView.java
# file  data/GroupTreeView.java  existed
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/JabRefDesktop.java
# file  data/JabRefDesktop.java  existed
# data/NativeDesktop.java
# data/ConnectToSharedDatabaseCommand.java
# data/URLUtil.java
# file  data/URLUtil.java  existed
# data/ManageJournalAbbreviationsViewModel.java
# file  data/ManageJournalAbbreviationsViewModel.java  existed
# data/URLUtil.java
# file  data/URLUtil.java  existed
# data/EntryEditor.java
# file  data/EntryEditor.java  existed
# data/GroupTreeView.java
# file  data/GroupTreeView.java  existed
# data/IconTheme.java
# file  data/IconTheme.java  existed
# data/UnknownExternalFileType.java
# data/Bootstrap.java
# file  data/Bootstrap.java  existed
# data/ControlHelper.java
# data/MainTableNameFormatter.java
# data/IconTheme.java
# file  data/IconTheme.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/AbbreviateAction.java
# file  data/AbbreviateAction.java  existed
# data/BackupUIManager.java
# data/CurrentThreadTaskExecutor.java
# file  data/CurrentThreadTaskExecutor.java  existed
# data/FindFullTextAction.java
# file  data/FindFullTextAction.java  existed
# data/NoDocumentException.java
# data/Bootstrap.java
# file  data/Bootstrap.java  existed
# data/DocumentViewerControl.java
# file  data/DocumentViewerControl.java  existed
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/UiThreadStringProperty.java
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/ManageProtectedTermsDialog.java
# data/AbstractPushToApplication.java
# file  data/AbstractPushToApplication.java  existed
# data/MergeEntries.java
# file  data/MergeEntries.java  existed
# data/GuiAppender.java
# data/MappedList.java
# file  data/MappedList.java  existed
# data/BindingsHelper.java
# file  data/BindingsHelper.java  existed
# data/MassSetFieldsDialog.java
# file  data/MassSetFieldsDialog.java  existed
# data/BibtexKeyPatternPrefTab.java
# file  data/BibtexKeyPatternPrefTab.java  existed
# data/ParseTexResultViewModel.java
# file  data/ParseTexResultViewModel.java  existed
# data/OpenOfficePanel.java
# file  data/OpenOfficePanel.java  existed
# data/PreviewPanel.java
# file  data/PreviewPanel.java  existed
# data/GroupDialog.java
# file  data/GroupDialog.java  existed
# data/DefaultFileUpdateMonitor.java
# file  data/DefaultFileUpdateMonitor.java  existed
# data/JabRefDesktop.java
# file  data/JabRefDesktop.java  existed
# data/MergeEntries.java
# file  data/MergeEntries.java  existed
# data/JabRefGUI.java
# file  data/JabRefGUI.java  existed
# data/IconTheme.java
# file  data/IconTheme.java  existed
# data/KeyBindingsDialogViewModel.java
# data/FileNodeViewModel.java
# data/DirectoryDialogConfiguration.java
# file  data/DirectoryDialogConfiguration.java  existed
# data/EntryEditor.java
# file  data/EntryEditor.java  existed
# data/Bootstrap.java
# file  data/Bootstrap.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/PushToLyx.java
# data/FileAnnotationTabViewModel.java
# data/ActionFactory.java
# file  data/ActionFactory.java  existed
# data/GroupTreeView.java
# file  data/GroupTreeView.java  existed
# data/LinkedFilesEditDialogViewModel.java
# file  data/LinkedFilesEditDialogViewModel.java  existed
# data/JabRefExecutorService.java
# file  data/JabRefExecutorService.java  existed
# data/SharedDatabaseLoginDialogViewModel.java
# data/CreationException.java
# data/FileTabViewModel.java
# file  data/FileTabViewModel.java  existed
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/FetchAndMergeEntry.java
# file  data/FetchAndMergeEntry.java  existed
# data/CitationsDisplay.java
# file  data/CitationsDisplay.java  existed
# data/FetchAndMergeEntry.java
# file  data/FetchAndMergeEntry.java  existed
# data/JabRefGUI.java
# file  data/JabRefGUI.java  existed
# data/CustomExternalFileType.java
# file  data/CustomExternalFileType.java  existed
# data/MainTableColumnFactory.java
# file  data/MainTableColumnFactory.java  existed
# data/AbbreviationsFileViewModel.java
# data/GroupTreeView.java
# file  data/GroupTreeView.java  existed
# data/ExternalFileTypes.java
# file  data/ExternalFileTypes.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/JabRefDesktop.java
# file  data/JabRefDesktop.java  existed
# data/GeneralTabViewModel.java
# file  data/GeneralTabViewModel.java  existed
# data/KeyBindingsDialogViewModel.java
# file  data/KeyBindingsDialogViewModel.java  existed
# data/ReplaceStringViewModel.java
# file  data/ReplaceStringViewModel.java  existed
# data/OpenDatabaseAction.java
# file  data/OpenDatabaseAction.java  existed
# data/MetaDataChangeViewModel.java
# data/Actions.java
# data/WebSearchPane.java
# file  data/WebSearchPane.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/MergeEntriesAction.java
# file  data/MergeEntriesAction.java  existed
# data/DatabaseChangeViewModel.java
# data/GroupTreeView.java
# file  data/GroupTreeView.java  existed
# data/JabRefMain.java
# file  data/JabRefMain.java  existed
# data/IconTheme.java
# file  data/IconTheme.java  existed
# data/JabRefDesktop.java
# file  data/JabRefDesktop.java  existed
# data/BackgroundTask.java
# file  data/BackgroundTask.java  existed
# data/TagBar.java
# data/ManageJournalAbbreviationsViewModel.java
# file  data/ManageJournalAbbreviationsViewModel.java  existed
# data/CellFactory.java
# file  data/CellFactory.java  existed
# data/GlobalSearchBar.java
# file  data/GlobalSearchBar.java  existed
# data/CellFactory.java
# file  data/CellFactory.java  existed
# data/IconTheme.java
# file  data/IconTheme.java  existed
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/OpenOfficePanel.java
# file  data/OpenOfficePanel.java  existed
# data/IconValidationDecorator.java
# data/DatabaseChangeViewModel.java
# file  data/DatabaseChangeViewModel.java  existed
# data/GroupTreeViewModel.java
# file  data/GroupTreeViewModel.java  existed
# data/RecursiveTreeItem.java
# data/GroupTreeNodeViewModel.java
# file  data/GroupTreeNodeViewModel.java  existed
# data/CellFactory.java
# file  data/CellFactory.java  existed
# data/GenerateBibtexKeyAction.java
# file  data/GenerateBibtexKeyAction.java  existed
# data/JournalEditorViewModel.java
# data/ParserResultWarningDialog.java
# file  data/ParserResultWarningDialog.java  existed
# data/GlobalSearchBar.java
# file  data/GlobalSearchBar.java  existed
# data/URLUtil.java
# file  data/URLUtil.java  existed
# data/ExportToClipboardAction.java
# file  data/ExportToClipboardAction.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/Tag.java
# data/GroupTreeViewModel.java
# file  data/GroupTreeViewModel.java  existed
# data/GroupTreeViewModel.java
# file  data/GroupTreeViewModel.java  existed
# data/CopyBibTeXKeyAndLinkAction.java
# file  data/CopyBibTeXKeyAndLinkAction.java  existed
# data/CustomExternalFileType.java
# file  data/CustomExternalFileType.java  existed
# data/PushToLyx.java
# file  data/PushToLyx.java  existed
# data/ErrorConsoleViewModel.java
# file  data/ErrorConsoleViewModel.java  existed
# data/BackgroundTask.java
# file  data/BackgroundTask.java  existed
# data/GroupTreeViewModel.java
# file  data/GroupTreeViewModel.java  existed
# data/StandardExternalFileType.java
# data/GenerateBibtexKeyAction.java
# file  data/GenerateBibtexKeyAction.java  existed
# data/BibtexKeyPatternPanel.java
# file  data/BibtexKeyPatternPanel.java  existed
# data/AppearancePrefsTab.java
# data/UndoableAddOrRemoveGroup.java
# file  data/UndoableAddOrRemoveGroup.java  existed
# data/SuggestionProvider.java
# file  data/SuggestionProvider.java  existed
# data/WriteXMPAction.java
# file  data/WriteXMPAction.java  existed
# data/ManageJournalAbbreviationsViewModel.java
# file  data/ManageJournalAbbreviationsViewModel.java  existed
# data/OpenDatabaseAction.java
# file  data/OpenDatabaseAction.java  existed
# data/ChangeScanner.java
# file  data/ChangeScanner.java  existed
# data/OpenDatabaseAction.java
# file  data/OpenDatabaseAction.java  existed
# data/BibtexKeyPatternPanel.java
# file  data/BibtexKeyPatternPanel.java  existed
# data/DocumentViewerControl.java
# file  data/DocumentViewerControl.java  existed
# data/AbstractPushToApplication.java
# file  data/AbstractPushToApplication.java  existed
# data/JabRefMain.java
# file  data/JabRefMain.java  existed
# data/SuggestionProvider.java
# file  data/SuggestionProvider.java  existed
# data/EntryEditor.java
# file  data/EntryEditor.java  existed
# data/GroupDialog.java
# file  data/GroupDialog.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/ManageKeywordsViewModel.java
# file  data/ManageKeywordsViewModel.java  existed
# data/SharedDatabaseLoginDialogView.java
# data/BibtexStringViewModel.java
# data/ExternalFileTypes.java
# file  data/ExternalFileTypes.java  existed
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/GroupNodeViewModel.java
# file  data/GroupNodeViewModel.java  existed
# data/ExternalFileTypes.java
# file  data/ExternalFileTypes.java  existed
# data/LinkedFileViewModel.java
# file  data/LinkedFileViewModel.java  existed
# data/UndoableModifySubtree.java
# file  data/UndoableModifySubtree.java  existed
# data/SidePaneManager.java
# file  data/SidePaneManager.java  existed
# data/EditorTextArea.java
# file  data/EditorTextArea.java  existed
# data/CellFactory.java
# file  data/CellFactory.java  existed
# data/ExternalFileTypes.java
# file  data/ExternalFileTypes.java  existed
# data/StringNameChangeViewModel.java
# data/ExternalFileTypes.java
# file  data/ExternalFileTypes.java  existed
# data/ImportHandler.java
# file  data/ImportHandler.java  existed
# data/NewSubLibraryAction.java
# data/FindUnlinkedFilesDialog.java
# file  data/FindUnlinkedFilesDialog.java  existed
# data/LinkedFileViewModel.java
# file  data/LinkedFileViewModel.java  existed
# data/EntryChangeViewModel.java
# file  data/EntryChangeViewModel.java  existed
# data/JabRefExecutorService.java
# file  data/JabRefExecutorService.java  existed
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/FieldsEditorTab.java
# file  data/FieldsEditorTab.java  existed
# data/EditorTextArea.java
# file  data/EditorTextArea.java  existed
# data/GroupTreeViewModel.java
# file  data/GroupTreeViewModel.java  existed
# data/ImportAction.java
# file  data/ImportAction.java  existed
# data/FieldFormatterCleanupsPanel.java
# file  data/FieldFormatterCleanupsPanel.java  existed
# data/GroupTreeViewModel.java
# file  data/GroupTreeViewModel.java  existed
# data/OSX.java
# data/GroupDialog.java
# file  data/GroupDialog.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/CellFactory.java
# file  data/CellFactory.java  existed
# data/ExternalFileTypes.java
# file  data/ExternalFileTypes.java  existed
# data/UndoableUnabbreviator.java
# data/AbbreviationsFileViewModel.java
# file  data/AbbreviationsFileViewModel.java  existed
# data/IconTheme.java
# file  data/IconTheme.java  existed
# data/FindUnlinkedFilesDialog.java
# file  data/FindUnlinkedFilesDialog.java  existed
# data/BibtexKeyPatternPrefTab.java
# file  data/BibtexKeyPatternPrefTab.java  existed
# data/CellFactory.java
# file  data/CellFactory.java  existed
# data/EditorMenus.java
# file  data/EditorMenus.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/OpenDatabaseAction.java
# file  data/OpenDatabaseAction.java  existed
# data/ImportAction.java
# file  data/ImportAction.java  existed
# data/UnlinkedFilesCrawler.java
# file  data/UnlinkedFilesCrawler.java  existed
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/IconTheme.java
# file  data/IconTheme.java  existed
# data/CellFactory.java
# file  data/CellFactory.java  existed
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/ImportHandler.java
# file  data/ImportHandler.java  existed
# data/UndoableAddOrRemoveGroup.java
# file  data/UndoableAddOrRemoveGroup.java  existed
# data/ParseTexDialogViewModel.java
# data/IconTheme.java
# file  data/IconTheme.java  existed
# data/LinkedFileViewModel.java
# file  data/LinkedFileViewModel.java  existed
# data/MainTable.java
# file  data/MainTable.java  existed
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/ExporterViewModel.java
# file  data/ExporterViewModel.java  existed
# data/BibtexKeyPatternPrefTab.java
# file  data/BibtexKeyPatternPrefTab.java  existed
# data/Bootstrap.java
# file  data/Bootstrap.java  existed
# data/GroupTreeView.java
# file  data/GroupTreeView.java  existed
# data/GroupDialog.java
# file  data/GroupDialog.java  existed
# data/ThemeLoader.java
# file  data/ThemeLoader.java  existed
# data/PreviewViewer.java
# file  data/PreviewViewer.java  existed
# data/ActionFactory.java
# file  data/ActionFactory.java  existed
# data/LinkedFilesEditor.java
# data/GuiAppender.java
# file  data/GuiAppender.java  existed
# data/GroupNodeViewModel.java
# file  data/GroupNodeViewModel.java  existed
# data/JabRefDesktop.java
# file  data/JabRefDesktop.java  existed
# data/IconTheme.java
# file  data/IconTheme.java  existed
# data/UndoableRemoveEntry.java
# data/EntryChangeViewModel.java
# file  data/EntryChangeViewModel.java  existed
# data/FieldsEditorTab.java
# file  data/FieldsEditorTab.java  existed
# data/MergeEntries.java
# file  data/MergeEntries.java  existed
# data/GlobalSearchBar.java
# file  data/GlobalSearchBar.java  existed
# data/EntryEditorTab.java
# file  data/EntryEditorTab.java  existed
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/CellFactory.java
# file  data/CellFactory.java  existed
# data/PushToApplication.java
# file  data/PushToApplication.java  existed
# data/UndoableAddOrRemoveGroup.java
# file  data/UndoableAddOrRemoveGroup.java  existed
# data/SmartConstrainedResizePolicy.java
# file  data/SmartConstrainedResizePolicy.java  existed
# data/Bootstrap.java
# file  data/Bootstrap.java  existed
# data/MainTable.java
# file  data/MainTable.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/ImportAction.java
# file  data/ImportAction.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/UndoableAddOrRemoveGroup.java
# file  data/UndoableAddOrRemoveGroup.java  existed
# data/AppearancePrefsTab.java
# file  data/AppearancePrefsTab.java  existed
# data/EntryEditor.java
# file  data/EntryEditor.java  existed
# data/EntryEditor.java
# file  data/EntryEditor.java  existed
# data/MainTable.java
# file  data/MainTable.java  existed
# data/ZipFileChooser.java
# file  data/ZipFileChooser.java  existed
# data/ExportToClipboardAction.java
# file  data/ExportToClipboardAction.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/ViewModelTableRowFactory.java
# file  data/ViewModelTableRowFactory.java  existed
# data/JabRefMain.java
# file  data/JabRefMain.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/Bootstrap.java
# file  data/Bootstrap.java  existed
# data/CitationStyleToClipboardWorker.java
# file  data/CitationStyleToClipboardWorker.java  existed
# data/ChangeEntryTypeMenu.java
# data/SidePaneManager.java
# file  data/SidePaneManager.java  existed
# data/PreferencesTab.java
# file  data/PreferencesTab.java  existed
# data/AppendDatabaseAction.java
# file  data/AppendDatabaseAction.java  existed
# data/JabRefDesktop.java
# file  data/JabRefDesktop.java  existed
# data/FileAnnotationTabView.java
# data/Bootstrap.java
# file  data/Bootstrap.java  existed
# data/UndoableAddOrRemoveGroup.java
# file  data/UndoableAddOrRemoveGroup.java  existed
# data/ImportHandler.java
# file  data/ImportHandler.java  existed
# data/HelpAction.java
# data/LinkedFilesEditorViewModel.java
# file  data/LinkedFilesEditorViewModel.java  existed
# data/CustomLocalDragboard.java
# file  data/CustomLocalDragboard.java  existed
# data/Bootstrap.java
# file  data/Bootstrap.java  existed
# data/GroupNodeViewModel.java
# file  data/GroupNodeViewModel.java  existed
# data/ImportEntriesViewModel.java
# file  data/ImportEntriesViewModel.java  existed
# data/GroupTreeNodeViewModel.java
# file  data/GroupTreeNodeViewModel.java  existed
# data/EntryEditor.java
# file  data/EntryEditor.java  existed
# data/EntryEditorTabList.java
# file  data/EntryEditorTabList.java  existed
# data/ExternalFileTypes.java
# file  data/ExternalFileTypes.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/SaveDatabaseAction.java
# file  data/SaveDatabaseAction.java  existed
# data/PushToApplication.java
# file  data/PushToApplication.java  existed
# data/OpenHyperlinksInExternalBrowser.java
# data/ViewModelTreeTableCellFactory.java
# data/IconTheme.java
# file  data/IconTheme.java  existed
# data/MathSciNetTab.java
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/PreviewViewer.java
# file  data/PreviewViewer.java  existed
# data/SuggestionProviders.java
# data/NoSelectionModel.java
# data/SidePaneManager.java
# file  data/SidePaneManager.java  existed
# data/SharedDatabaseLoginDialogViewModel.java
# file  data/SharedDatabaseLoginDialogViewModel.java  existed
# data/FetchAndMergeEntry.java
# file  data/FetchAndMergeEntry.java  existed
# data/RelatedArticlesTab.java
# file  data/RelatedArticlesTab.java  existed
# data/UndoableMoveGroup.java
# data/TemporalAccessorPicker.java
# file  data/TemporalAccessorPicker.java  existed
# data/SimpleCommand.java
# data/MergeEntriesAction.java
# file  data/MergeEntriesAction.java  existed
# data/MassSetFieldsDialog.java
# file  data/MassSetFieldsDialog.java  existed
# data/StringRemoveChangeViewModel.java
# data/AbbreviationViewModel.java
# data/LinkedEntriesEditorViewModel.java
# file  data/LinkedEntriesEditorViewModel.java  existed
# data/PreviewTabViewModel.java
# file  data/PreviewTabViewModel.java  existed
# data/DroppingMouseLocation.java
# data/BibtexKeyPatternPrefTab.java
# file  data/BibtexKeyPatternPrefTab.java  existed
# data/WebSearchPaneViewModel.java
# data/UnlinkedFilesCrawler.java
# file  data/UnlinkedFilesCrawler.java  existed
# data/RequiredFieldsTab.java
# file  data/RequiredFieldsTab.java  existed
# data/DocumentViewModel.java
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/MainTableDataModel.java
# data/RelatedArticlesTab.java
# file  data/RelatedArticlesTab.java  existed
# data/UndoableRemoveString.java
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/UndoableAddOrRemoveGroup.java
# file  data/UndoableAddOrRemoveGroup.java  existed
# data/ManageJournalAbbreviationsViewModel.java
# file  data/ManageJournalAbbreviationsViewModel.java  existed
# data/SmartConstrainedResizePolicy.java
# file  data/SmartConstrainedResizePolicy.java  existed
# data/SpecialFieldAction.java
# file  data/SpecialFieldAction.java  existed
# data/ContentSelectorSuggestionProvider.java
# data/UndoableFieldChange.java
# file  data/UndoableFieldChange.java  existed
# data/EditorTextField.java
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/FieldEditors.java
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/ApplicationInsightsAppender.java
# data/PreferencesDialogView.java
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/AbstractPushToApplication.java
# file  data/AbstractPushToApplication.java  existed
# data/GroupTreeView.java
# file  data/GroupTreeView.java  existed
# data/CitationStyleToClipboardWorker.java
# file  data/CitationStyleToClipboardWorker.java  existed
# data/CustomExternalFileType.java
# file  data/CustomExternalFileType.java  existed
# data/PushToVim.java
# data/AbstractPushToApplication.java
# file  data/AbstractPushToApplication.java  existed
# data/UnlinkedPDFFileFilter.java
# data/GroupTreeNodeViewModel.java
# file  data/GroupTreeNodeViewModel.java  existed
# data/AutoCompleteFirstNameMode.java
# file  data/AutoCompleteFirstNameMode.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/CountingUndoManager.java
# data/ManageJournalAbbreviationsViewModel.java
# file  data/ManageJournalAbbreviationsViewModel.java  existed
# data/SidePaneManager.java
# file  data/SidePaneManager.java  existed
# data/ImportAction.java
# file  data/ImportAction.java  existed
# data/OpenDatabaseAction.java
# file  data/OpenDatabaseAction.java  existed
# data/CellFactory.java
# file  data/CellFactory.java  existed
# data/MergeEntries.java
# file  data/MergeEntries.java  existed
# data/SuggestionProvider.java
# file  data/SuggestionProvider.java  existed
# data/ThemeLoader.java
# file  data/ThemeLoader.java  existed
# data/GroupNodeViewModel.java
# file  data/GroupNodeViewModel.java  existed
# data/FileFilterConverter.java
# data/VersionWorker.java
# file  data/VersionWorker.java  existed
# data/URLUtil.java
# file  data/URLUtil.java  existed
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/FileAnnotationTabViewModel.java
# file  data/FileAnnotationTabViewModel.java  existed
# data/EntryEditor.java
# file  data/EntryEditor.java  existed
# data/SharedDatabaseLoginDialogView.java
# file  data/SharedDatabaseLoginDialogView.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/ErrorConsoleViewModel.java
# file  data/ErrorConsoleViewModel.java  existed
# data/JabRefGUI.java
# file  data/JabRefGUI.java  existed
# data/KeyBinding.java
# file  data/KeyBinding.java  existed
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/WebSearchPane.java
# file  data/WebSearchPane.java  existed
# data/UndoableAddOrRemoveGroup.java
# file  data/UndoableAddOrRemoveGroup.java  existed
# data/MassSetFieldsDialog.java
# file  data/MassSetFieldsDialog.java  existed
# data/UndoableAddOrRemoveGroup.java
# file  data/UndoableAddOrRemoveGroup.java  existed
# data/PreviewTabViewModel.java
# file  data/PreviewTabViewModel.java  existed
# data/IconTheme.java
# file  data/IconTheme.java  existed
# data/CurrentThreadTaskExecutor.java
# file  data/CurrentThreadTaskExecutor.java  existed
# data/KeyBinding.java
# file  data/KeyBinding.java  existed
# data/GroupTreeViewModel.java
# file  data/GroupTreeViewModel.java  existed
# data/SourceTab.java
# file  data/SourceTab.java  existed
# data/MassSetFieldsDialog.java
# file  data/MassSetFieldsDialog.java  existed
# data/UndoableStringChange.java
# data/DuplicateSearch.java
# file  data/DuplicateSearch.java  existed
# data/FileAnnotationViewModel.java
# data/BackgroundTask.java
# file  data/BackgroundTask.java  existed
# data/CheckForNewEntryTypesAction.java
# data/OpenDatabaseAction.java
# file  data/OpenDatabaseAction.java  existed
# data/EntryEditor.java
# file  data/EntryEditor.java  existed
# data/GroupNodeViewModel.java
# file  data/GroupNodeViewModel.java  existed
# data/FindFullTextAction.java
# file  data/FindFullTextAction.java  existed
# data/CustomizeExternalFileTypesDialog.java
# data/GroupDialog.java
# file  data/GroupDialog.java  existed
# data/BackgroundTask.java
# file  data/BackgroundTask.java  existed
# data/EntryEditorTab.java
# file  data/EntryEditorTab.java  existed
# data/Bootstrap.java
# file  data/Bootstrap.java  existed
# data/ParserResultWarningDialog.java
# file  data/ParserResultWarningDialog.java  existed
# data/MainTable.java
# file  data/MainTable.java  existed
# data/AutosaveUIManager.java
# data/ImportHandler.java
# file  data/ImportHandler.java  existed
# data/RightClickMenu.java
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/JabRefMain.java
# file  data/JabRefMain.java  existed
# data/EntryEditor.java
# file  data/EntryEditor.java  existed
# data/MergeEntries.java
# file  data/MergeEntries.java  existed
# data/URLUtil.java
# file  data/URLUtil.java  existed
# data/MainTableDataModel.java
# file  data/MainTableDataModel.java  existed
# data/MergeEntries.java
# file  data/MergeEntries.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/ManageJournalAbbreviationsViewModel.java
# file  data/ManageJournalAbbreviationsViewModel.java  existed
# data/MergeEntries.java
# file  data/MergeEntries.java  existed
# data/SaveDatabaseAction.java
# file  data/SaveDatabaseAction.java  existed
# data/CreateModifyExporterDialogViewModel.java
# file  data/CreateModifyExporterDialogViewModel.java  existed
# data/ImportEntriesViewModel.java
# file  data/ImportEntriesViewModel.java  existed
# data/UndoableInsertEntry.java
# data/PushToApplicationSettings.java
# data/SuggestionProvider.java
# file  data/SuggestionProvider.java  existed
# data/MainTableNameFormatter.java
# file  data/MainTableNameFormatter.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/LibraryPropertiesDialogView.java
# file  data/LibraryPropertiesDialogView.java  existed
# data/CleanupPresetPanel.java
# data/GlobalSearchBar.java
# file  data/GlobalSearchBar.java  existed
# data/AppendDatabaseAction.java
# file  data/AppendDatabaseAction.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/JabRefMain.java
# file  data/JabRefMain.java  existed
# data/JabRefFrame.java
# file  data/JabRefFrame.java  existed
# data/LinkedFileViewModel.java
# file  data/LinkedFileViewModel.java  existed
# data/FieldsEditorTab.java
# file  data/FieldsEditorTab.java  existed
# data/DocumentPageViewModel.java
# file  data/DocumentPageViewModel.java  existed
# data/URLUtil.java
# file  data/URLUtil.java  existed
# data/MathSciNetTab.java
# file  data/MathSciNetTab.java  existed
# data/FetchAndMergeEntry.java
# file  data/FetchAndMergeEntry.java  existed
# data/OpenOfficePanel.java
# file  data/OpenOfficePanel.java  existed
# data/Windows.java
# data/AbbreviationsFileViewModel.java
# file  data/AbbreviationsFileViewModel.java  existed
# data/OOBibBase.java
# file  data/OOBibBase.java  existed
# data/LinkedFilesEditor.java
# file  data/LinkedFilesEditor.java  existed
# data/GlobalSearchBar.java
# file  data/GlobalSearchBar.java  existed
# data/PreviewViewer.java
# file  data/PreviewViewer.java  existed
# data/SpecialFieldAction.java
# file  data/SpecialFieldAction.java  existed
# data/DocumentViewerControl.java
# file  data/DocumentViewerControl.java  existed
# data/ActionFactory.java
# file  data/ActionFactory.java  existed
# data/UndefinedCharacterFormatException.java
# data/TaskExecutor.java
# file  data/TaskExecutor.java  existed
# data/IconTheme.java
# file  data/IconTheme.java  existed
# data/AutoLinkFilesAction.java
# data/Bootstrap.java
# file  data/Bootstrap.java  existed
# data/module-info.java
# data/module-info.java
# file  data/module-info.java  existed
# data/module-info.java
# file  data/module-info.java  existed
# data/module-info.java
# file  data/module-info.java  existed
# data/DatabaseChangeEvent.java
# data/DatabaseChangeEvent.java
# file  data/DatabaseChangeEvent.java  existed
# data/DatabaseChangeListener.java
# data/DatabaseChangeRegistration.java
# data/DatabaseChangeRegistration.java
# file  data/DatabaseChangeRegistration.java  existed
# data/Benchmarks.java
# data/Benchmarks.java
# file  data/Benchmarks.java  existed
# data/OracleConnection.java
# data/OracleDriver.java
# data/OracleStatement.java
# data/package-info.java
# data/AbstractViewModel.java
# data/ApacheCommonsLang3Allowed.java
# data/ApacheCommonsLang3Allowed.java
# file  data/ApacheCommonsLang3Allowed.java  existed
# data/AuxCommandLine.java
# data/BasePanelMode.java
# data/ClipBoardManager.java
# data/ClipBoardManager.java
# file  data/ClipBoardManager.java  existed
# data/ArgumentProcessor.java
# data/ArgumentProcessor.java
# file  data/ArgumentProcessor.java  existed
# data/ArgumentProcessor.java
# file  data/ArgumentProcessor.java  existed
# data/ArgumentProcessor.java
# file  data/ArgumentProcessor.java  existed
# data/ArgumentProcessor.java
# file  data/ArgumentProcessor.java  existed
# data/ArgumentProcessor.java
# file  data/ArgumentProcessor.java  existed
# data/ArgumentProcessor.java
# file  data/ArgumentProcessor.java  existed
# data/ArgumentProcessor.java
# file  data/ArgumentProcessor.java  existed
# data/ArgumentProcessor.java
# file  data/ArgumentProcessor.java  existed
# data/ArgumentProcessor.java
# file  data/ArgumentProcessor.java  existed
# data/ArgumentProcessor.java
# file  data/ArgumentProcessor.java  existed
# data/ArgumentProcessor.java
# file  data/ArgumentProcessor.java  existed
# data/ArgumentProcessor.java
# file  data/ArgumentProcessor.java  existed
# data/ArgumentProcessor.java
# file  data/ArgumentProcessor.java  existed
# data/ArgumentProcessor.java
# file  data/ArgumentProcessor.java  existed
# data/ArgumentProcessor.java
# file  data/ArgumentProcessor.java  existed
# data/ArgumentProcessor.java
# file  data/ArgumentProcessor.java  existed
# data/ArgumentProcessor.java
# file  data/ArgumentProcessor.java  existed
# data/ArgumentProcessor.java
# file  data/ArgumentProcessor.java  existed
# data/BasePanel.java
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/BasePanel.java
# file  data/BasePanel.java  existed
# data/CrossrefFetcherEvaluator.java
# data/DefaultInjector.java
# data/DefaultInjector.java
# file  data/DefaultInjector.java  existed
# data/DialogService.java
# data/DialogService.java
# file  data/DialogService.java  existed
# data/DialogService.java
# file  data/DialogService.java  existed
# data/DialogService.java
# file  data/DialogService.java  existed
# data/DialogService.java
# file  data/DialogService.java  existed
# data/DialogService.java
# file  data/DialogService.java  existed
# data/DialogService.java
# file  data/DialogService.java  existed
# data/DialogService.java
# file  data/DialogService.java  existed
# data/DialogService.java
# file  data/DialogService.java  existed
# data/DialogService.java
# file  data/DialogService.java  existed
# data/DialogService.java
# file  data/DialogService.java  existed
# data/DialogService.java
# file  data/DialogService.java  existed
# data/DialogService.java
# file  data/DialogService.java  existed
# data/DialogService.java
# file  data/DialogService.java  existed
# data/DialogService.java
# file  data/DialogService.java  existed
# data/DialogService.java
# file  data/DialogService.java  existed
# data/DialogService.java
# file  data/DialogService.java  existed
# data/DialogService.java
# file  data/DialogService.java  existed
# data/DialogService.java
# file  data/DialogService.java  existed
# data/DialogService.java
# file  data/DialogService.java  existed
# data/DialogService.java
# file  data/DialogService.java  existed
# data/DialogService.java
# file  data/DialogService.java  existed
# data/DialogService.java
# file  data/DialogService.java  existed
# data/DialogService.java
# file  data/DialogService.java  existed
# data/DragAndDropDataFormats.java
# data/EntryTypeView.java
# data/EntryTypeView.java
# file  data/EntryTypeView.java  existed
# data/EntryTypeView.java
# file  data/EntryTypeView.java  existed
# data/EntryTypeViewModel.java
# data/FXDialog.java
# data/Globals.java
# data/Globals.java
# file  data/Globals.java  existed
# data/Globals.java
# file  data/Globals.java  existed
# data/Globals.java
# file  data/Globals.java  existed
# data/Globals.java
# file  data/Globals.java  existed
# data/Globals.java
# file  data/Globals.java  existed
# data/Globals.java
# file  data/Globals.java  existed
# data/Globals.java
# file  data/Globals.java  existed
# data/Globals.java
# file  data/Globals.java  existed
# data/GUIGlobals.java
# data/GUIGlobals.java
# file  data/GUIGlobals.java  existed
# data/GUIGlobals.java
# file  data/GUIGlobals.java  existed
# data/GUIGlobals.java
# file  data/GUIGlobals.java  existed
# data/GUIGlobals.java
# file  data/GUIGlobals.java  existed
# data/GUIGlobals.java
# file  data/GUIGlobals.java  existed
# data/JabRefCLI.java
# data/JabRefCLI.java
# file  data/JabRefCLI.java  existed
# data/JabRefDialogService.java
# data/JabRefDialogService.java
# file  data/JabRefDialogService.java  existed
# data/JabRefDialogService.java
# file  data/JabRefDialogService.java  existed
# data/JabRefDialogService.java
# file  data/JabRefDialogService.java  existed
# data/JabRefLauncher.java
# data/SidePane.java
# data/SidePaneComponent.java
# data/SidePaneComponent.java
# file  data/SidePaneComponent.java  existed
# data/SidePaneComponent.java
# file  data/SidePaneComponent.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed
# data/OracleConnection.java
# file  data/OracleConnection.java  existed

# %%
# count unique files.
path = "assets/declutter-gold_DevelopmentSet.csv"
dataframe = pd.read_csv(path, na_filter = False)
li = []
for name in dataframe["path_to_file"]:
    if name not in li:
        li.append(name)
print(len(li))
# Out:
# 279
