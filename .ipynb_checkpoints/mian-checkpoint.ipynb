# %%
import pandas as pd
import spacy
import time
import re

# %%
#Find camelCase words
def camel_case_split(word):
    matches = re.finditer('.+?(?:(?<=[a-z])(?=[A-Z])|(?<=[A-Z])(?=[A-Z][a-z])|$)', word)
    words = [m.group(0) for m in matches]
    splitedWord = ''
    if len(words) > 1:
        i = 0
        for w in words:
            if i == 0:
                splitedWord = w
            else:
                splitedWord += ' ' + w
            i += 1
    else:
        splitedWord = words[0]
    
    print('Word after camelCase split:', splitedWord)
    return splitedWord

# %%
#Remove symbols which are defined in "seps" from given word
def remove_symbol_from_word(word):
    seps = ["#", ".", '(', ')', '{', '}', '[', ']', '\'', '/', '_', '-', '"', '=']
    trimedWord = ''
    for sep in seps:
        word = word.replace(sep,' ')
    
    print('Word after symbol remover:', word)
    return word

# %%
#Remove single char word (for example: if "e.g." is modified to "e g", we can remove then "e" and "g")
def remove_single_char_words(comment):
    splitedComment = comment.split()
    newComment = ''
    idx = 0
    for w in splitedComment:
        if len(w) == 1:
            print('Remove single char:', w)
        else:
            if idx == 0:
                newComment += w
            else:
                newComment = newComment + ' ' + w
        idx += 1
    return newComment

# %%
#Remove duplicate white spaces in a sentence
def remove_more_than_one_space_in_sentence(comment):
    comment = re.sub(' +', ' ', comment)
    return comment

# %%
#Write all words in the comment to lower case
def all_to_lower_case(comment):
    return comment.lower()

# %%
#If a url is given in the comment -> remove it
def remove_url_from_comment(word):
    return re.sub(r'^https?:\/\/.*[\r\n]*', '', word, flags=re.MULTILINE)

# %%
#Replace word with another word (spaCy defines doesn't as two words: does and n't)
def replace_word_with(word):
    if word == 'n\'t':
        word = word.replace('n\'t', 'not')
    elif word == '\'ll':
        word = word.replace('\'ll', 'will')
    print('Word after replace with func:', word)
    return word

# %%
# Load dataset
#url = "assets/declutter-gold_DevelopmentSet.csv"
url = "csv/newFIle.csv"

#define column lables
names = ['comment', 'code', 'non-information']

#na_filter = false, because pandas read empty string as float (nan)!
#skiprows = 1, because the first row contains only the labels
dataframe = pd.read_csv(url, names=names, skiprows = 1, na_filter = False)



#load EN model to analyse sentences in english language
nlp = spacy.load("en_core_web_sm")


seps = ["#", ".", '(', ')']

start_time = time.time()
# Get all values from the column "comment" and print
columns =  dataframe['comment'].tolist()
#Loop over each comment entries
for idx, val in enumerate(columns):
    print(idx, val)
    print()
    doc = nlp(val)
    trimedComment = ''

    #Loop over each word
    for w in doc:
        #Remove PUNCT, AUX, DET via spaCy
        if w.pos_ == 'PUNCT' or w.pos_ == 'DET':
            print('Removed word via spaCy:', w.text)
            print()
            continue
        print('Word:', w.text)
        
        #Replace word with
        word = replace_word_with(w.text)
        #CamelCase remover
        word = camel_case_split(word)
        #URL remover
        word = remove_url_from_comment(word)
        #Symbol remover
        word = remove_symbol_from_word(word)
        
        print()
        trimedComment += ' ' + word
    
    trimedComment = remove_more_than_one_space_in_sentence(trimedComment)
    trimedComment = all_to_lower_case(trimedComment)
    trimedComment = remove_single_char_words(trimedComment)
    print()
    print('Finished modified comment:', trimedComment)
    #print([(w.text, w.pos_) for w in doc])
    print()
    dataframe.at[idx, 'comment'] = trimedComment

elapsed_time = time.time() - start_time
print(elapsed_time)

#Save modified comment into file
keep_col = ['comment','code','non-information']
new_f = dataframe[keep_col]
new_f.to_csv("csv/trimedComments.csv", index=False)



#Print all rows and not only the first 5 and the last 5
#pd.set_option('display.max_rows', None)

#other option settings if necessary:
#pd.set_option('display.max_columns', None)
#pd.set_option('display.width', None)
#pd.set_option('display.max_colwidth', -1)

# Only print comment and non-information column
#print(dataframe[['comment', 'non-information']])
#print(dataframe[['comment']])

# Print all information from csv file in a DataFrame (table object)
#print(dataframe)
# Out:
# 0
#
#
# Finished modified comment:
#
# 1
#
#
# Finished modified comment:
#
# 2
#
#
# Finished modified comment:
#
# 3
#
#
# Finished modified comment:
#
# 4
#
#
# Finished modified comment:
#
# 5
#
#
# Finished modified comment:
#
# 6
#
#
# Finished modified comment:
#
# 7
#
#
# Finished modified comment:
#
# 8
#
#
# Finished modified comment:
#
# 9
#
#
# Finished modified comment:
#
# 10
#
#
# Finished modified comment:
#
# 11
#
#
# Finished modified comment:
#
# 12
#
#
# Finished modified comment:
#
# 13
#
#
# Finished modified comment:
#
# 14
#
#
# Finished modified comment:
#
# 15
#
#
# Finished modified comment:
#
# 16
#
#
# Finished modified comment:
#
# 17
#
#
# Finished modified comment:
#
# 18
#
#
# Finished modified comment:
#
# 19
#
#
# Finished modified comment:
#
# 20
#
#
# Finished modified comment:
#
# 21
#
#
# Finished modified comment:
#
# 22
#
#
# Finished modified comment:
#
# 23
#
#
# Finished modified comment:
#
# 24
#
#
# Finished modified comment:
#
# 25
#
#
# Finished modified comment:
#
# 26
#
#
# Finished modified comment:
#
# 27
#
#
# Finished modified comment:
#
# 28
#
#
# Finished modified comment:
#
# 29
#
#
# Finished modified comment:
#
# 30
#
#
# Finished modified comment:
#
# 31
#
#
# Finished modified comment:
#
# 32
#
#
# Finished modified comment:
#
# 33
#
#
# Finished modified comment:
#
# 34
#
#
# Finished modified comment:
#
# 35
#
#
# Finished modified comment:
#
# 36
#
#
# Finished modified comment:
#
# 37
#
#
# Finished modified comment:
#
# 38
#
#
# Finished modified comment:
#
# 39
#
#
# Finished modified comment:
#
# 40
#
#
# Finished modified comment:
#
# 41
#
#
# Finished modified comment:
#
# 42
#
#
# Finished modified comment:
#
# 43
#
#
# Finished modified comment:
#
# 44
#
#
# Finished modified comment:
#
# 45
#
#
# Finished modified comment:
#
# 46
#
#
# Finished modified comment:
#
# 47
#
#
# Finished modified comment:
#
# 48
#
#
# Finished modified comment:
#
# 49
#
#
# Finished modified comment:
#
# 50
#
#
# Finished modified comment:
#
# 51
#
#
# Finished modified comment:
#
# 52
#
#
# Finished modified comment:
#
# 53
#
#
# Finished modified comment:
#
# 54
#
#
# Finished modified comment:
#
# 55
#
#
# Finished modified comment:
#
# 56
#
#
# Finished modified comment:
#
# 57
#
#
# Finished modified comment:
#
# 58
#
#
# Finished modified comment:
#
# 59
#
#
# Finished modified comment:
#
# 60
#
#
# Finished modified comment:
#
# 61
#
#
# Finished modified comment:
#
# 62
#
#
# Finished modified comment:
#
# 63
#
#
# Finished modified comment:
#
# 64
#
#
# Finished modified comment:
#
# 65
#
#
# Finished modified comment:
#
# 66
#
#
# Finished modified comment:
#
# 67
#
#
# Finished modified comment:
#
# 68
#
#
# Finished modified comment:
#
# 69
#
#
# Finished modified comment:
#
# 70
#
#
# Finished modified comment:
#
# 71
#
#
# Finished modified comment:
#
# 72
#
#
# Finished modified comment:
#
# 73
#
#
# Finished modified comment:
#
# 74
#
#
# Finished modified comment:
#
# 75
#
#
# Finished modified comment:
#
# 76
#
#
# Finished modified comment:
#
# 77
#
#
# Finished modified comment:
#
# 78
#
#
# Finished modified comment:
#
# 79
#
#
# Finished modified comment:
#
# 80
#
#
# Finished modified comment:
#
# 81
#
#
# Finished modified comment:
#
# 82
#
#
# Finished modified comment:
#
# 83
#
#
# Finished modified comment:
#
# 84
#
#
# Finished modified comment:
#
# 85
#
#
# Finished modified comment:
#
# 86
#
#
# Finished modified comment:
#
# 87
#
#
# Finished modified comment:
#
# 88
#
#
# Finished modified comment:
#
# 89
#
#
# Finished modified comment:
#
# 90
#
#
# Finished modified comment:
#
# 91
#
#
# Finished modified comment:
#
# 92
#
#
# Finished modified comment:
#
# 93
#
#
# Finished modified comment:
#
# 94
#
#
# Finished modified comment:
#
# 95
#
#
# Finished modified comment:
#
# 96
#
#
# Finished modified comment:
#
# 97
#
#
# Finished modified comment:
#
# 98
#
#
# Finished modified comment:
#
# 99
#
#
# Finished modified comment:
#
# 100
#
#
# Finished modified comment:
#
# 101
#
#
# Finished modified comment:
#
# 102
#
#
# Finished modified comment:
#
# 103
#
#
# Finished modified comment:
#
# 104
#
#
# Finished modified comment:
#
# 105
#
#
# Finished modified comment:
#
# 106
#
#
# Finished modified comment:
#
# 107
#
#
# Finished modified comment:
#
# 108
#
#
# Finished modified comment:
#
# 109
#
#
# Finished modified comment:
#
# 110
#
#
# Finished modified comment:
#
# 111
#
#
# Finished modified comment:
#
# 112
#
#
# Finished modified comment:
#
# 113
#
#
# Finished modified comment:
#
# 114
#
#
# Finished modified comment:
#
# 115
#
#
# Finished modified comment:
#
# 116
#
#
# Finished modified comment:
#
# 117
#
#
# Finished modified comment:
#
# 118
#
#
# Finished modified comment:
#
# 119
#
#
# Finished modified comment:
#
# 120
#
#
# Finished modified comment:
#
# 121
#
#
# Finished modified comment:
#
# 122
#
#
# Finished modified comment:
#
# 123
#
#
# Finished modified comment:
#
# 124
#
#
# Finished modified comment:
#
# 125
#
#
# Finished modified comment:
#
# 126
#
#
# Finished modified comment:
#
# 127
#
#
# Finished modified comment:
#
# 128
#
#
# Finished modified comment:
#
# 129
#
#
# Finished modified comment:
#
# 130
#
#
# Finished modified comment:
#
# 131
#
#
# Finished modified comment:
#
# 132
#
#
# Finished modified comment:
#
# 133
#
#
# Finished modified comment:
#
# 134
#
#
# Finished modified comment:
#
# 135
#
#
# Finished modified comment:
#
# 136
#
#
# Finished modified comment:
#
# 137
#
#
# Finished modified comment:
#
# 138
#
#
# Finished modified comment:
#
# 139
#
#
# Finished modified comment:
#
# 140
#
#
# Finished modified comment:
#
# 141
#
#
# Finished modified comment:
#
# 142
#
#
# Finished modified comment:
#
# 143
#
#
# Finished modified comment:
#
# 144
#
#
# Finished modified comment:
#
# 145
#
#
# Finished modified comment:
#
# 146
#
#
# Finished modified comment:
#
# 147
#
#
# Finished modified comment:
#
# 148
#
#
# Finished modified comment:
#
# 149
#
#
# Finished modified comment:
#
# 150
#
#
# Finished modified comment:
#
# 151
#
#
# Finished modified comment:
#
# 152
#
#
# Finished modified comment:
#
# 153
#
#
# Finished modified comment:
#
# 154
#
#
# Finished modified comment:
#
# 155
#
#
# Finished modified comment:
#
# 156
#
#
# Finished modified comment:
#
# 157
#
#
# Finished modified comment:
#
# 158
#
#
# Finished modified comment:
#
# 159
#
#
# Finished modified comment:
#
# 160
#
#
# Finished modified comment:
#
# 161
#
#
# Finished modified comment:
#
# 162
#
#
# Finished modified comment:
#
# 163
#
#
# Finished modified comment:
#
# 164
#
#
# Finished modified comment:
#
# 165
#
#
# Finished modified comment:
#
# 166
#
#
# Finished modified comment:
#
# 167
#
#
# Finished modified comment:
#
# 168
#
#
# Finished modified comment:
#
# 169
#
#
# Finished modified comment:
#
# 170
#
#
# Finished modified comment:
#
# 171
#
#
# Finished modified comment:
#
# 172
#
#
# Finished modified comment:
#
# 173
#
#
# Finished modified comment:
#
# 174
#
#
# Finished modified comment:
#
# 175
#
#
# Finished modified comment:
#
# 176
#
#
# Finished modified comment:
#
# 177
#
#
# Finished modified comment:
#
# 178
#
#
# Finished modified comment:
#
# 179
#
#
# Finished modified comment:
#
# 180
#
#
# Finished modified comment:
#
# 181
#
#
# Finished modified comment:
#
# 182
#
#
# Finished modified comment:
#
# 183
#
#
# Finished modified comment:
#
# 184
#
#
# Finished modified comment:
#
# 185
#
#
# Finished modified comment:
#
# 186
#
#
# Finished modified comment:
#
# 187
#
#
# Finished modified comment:
#
# 188
#
#
# Finished modified comment:
#
# 189
#
#
# Finished modified comment:
#
# 190
#
#
# Finished modified comment:
#
# 191
#
#
# Finished modified comment:
#
# 192
#
#
# Finished modified comment:
#
# 193
#
#
# Finished modified comment:
#
# 194
#
#
# Finished modified comment:
#
# 195
#
#
# Finished modified comment:
#
# 196
#
#
# Finished modified comment:
#
# 197
#
#
# Finished modified comment:
#
# 198
#
#
# Finished modified comment:
#
# 199
#
#
# Finished modified comment:
#
# 200
#
#
# Finished modified comment:
#
# 201
#
#
# Finished modified comment:
#
# 202
#
#
# Finished modified comment:
#
# 203
#
#
# Finished modified comment:
#
# 204
#
#
# Finished modified comment:
#
# 205
#
#
# Finished modified comment:
#
# 206
#
#
# Finished modified comment:
#
# 207
#
#
# Finished modified comment:
#
# 208
#
#
# Finished modified comment:
#
# 209
#
#
# Finished modified comment:
#
# 210
#
#
# Finished modified comment:
#
# 211
#
#
# Finished modified comment:
#
# 212
#
#
# Finished modified comment:
#
# 213
#
#
# Finished modified comment:
#
# 214
#
#
# Finished modified comment:
#
# 215
#
#
# Finished modified comment:
#
# 216
#
#
# Finished modified comment:
#
# 217
#
#
# Finished modified comment:
#
# 218
#
#
# Finished modified comment:
#
# 219
#
#
# Finished modified comment:
#
# 220
#
#
# Finished modified comment:
#
# 221
#
#
# Finished modified comment:
#
# 222
#
#
# Finished modified comment:
#
# 223
#
#
# Finished modified comment:
#
# 224
#
#
# Finished modified comment:
#
# 225
#
#
# Finished modified comment:
#
# 226
#
#
# Finished modified comment:
#
# 227
#
#
# Finished modified comment:
#
# 228
#
#
# Finished modified comment:
#
# 229
#
#
# Finished modified comment:
#
# 230
#
#
# Finished modified comment:
#
# 231
#
#
# Finished modified comment:
#
# 232
#
#
# Finished modified comment:
#
# 233
#
#
# Finished modified comment:
#
# 234
#
#
# Finished modified comment:
#
# 235
#
#
# Finished modified comment:
#
# 236
#
#
# Finished modified comment:
#
# 237
#
#
# Finished modified comment:
#
# 238
#
#
# Finished modified comment:
#
# 239
#
#
# Finished modified comment:
#
# 240
#
#
# Finished modified comment:
#
# 241
#
#
# Finished modified comment:
#
# 242
#
#
# Finished modified comment:
#
# 243
#
#
# Finished modified comment:
#
# 244
#
#
# Finished modified comment:
#
# 245
#
#
# Finished modified comment:
#
# 246
#
#
# Finished modified comment:
#
# 247
#
#
# Finished modified comment:
#
# 248
#
#
# Finished modified comment:
#
# 249
#
#
# Finished modified comment:
#
# 250
#
#
# Finished modified comment:
#
# 251
#
#
# Finished modified comment:
#
# 252
#
#
# Finished modified comment:
#
# 253
#
#
# Finished modified comment:
#
# 254
#
#
# Finished modified comment:
#
# 255
#
#
# Finished modified comment:
#
# 256
#
#
# Finished modified comment:
#
# 257
#
#
# Finished modified comment:
#
# 258
#
#
# Finished modified comment:
#
# 259
#
#
# Finished modified comment:
#
# 260
#
#
# Finished modified comment:
#
# 261
#
#
# Finished modified comment:
#
# 262
#
#
# Finished modified comment:
#
# 263
#
#
# Finished modified comment:
#
# 264
#
#
# Finished modified comment:
#
# 265
#
#
# Finished modified comment:
#
# 266
#
#
# Finished modified comment:
#
# 267
#
#
# Finished modified comment:
#
# 268
#
#
# Finished modified comment:
#
# 269
#
#
# Finished modified comment:
#
# 270
#
#
# Finished modified comment:
#
# 271
#
#
# Finished modified comment:
#
# 272
#
#
# Finished modified comment:
#
# 273
#
#
# Finished modified comment:
#
# 274
#
#
# Finished modified comment:
#
# 275
#
#
# Finished modified comment:
#
# 276
#
#
# Finished modified comment:
#
# 277
#
#
# Finished modified comment:
#
# 278
#
#
# Finished modified comment:
#
# 279
#
#
# Finished modified comment:
#
# 280
#
#
# Finished modified comment:
#
# 281
#
#
# Finished modified comment:
#
# 282
#
#
# Finished modified comment:
#
# 283
#
#
# Finished modified comment:
#
# 284
#
#
# Finished modified comment:
#
# 285
#
#
# Finished modified comment:
#
# 286
#
#
# Finished modified comment:
#
# 287
#
#
# Finished modified comment:
#
# 288
#
#
# Finished modified comment:
#
# 289
#
#
# Finished modified comment:
#
# 290
#
#
# Finished modified comment:
#
# 291
#
#
# Finished modified comment:
#
# 292
#
#
# Finished modified comment:
#
# 293
#
#
# Finished modified comment:
#
# 294
#
#
# Finished modified comment:
#
# 295
#
#
# Finished modified comment:
#
# 296
#
#
# Finished modified comment:
#
# 297
#
#
# Finished modified comment:
#
# 298
#
#
# Finished modified comment:
#
# 299
#
#
# Finished modified comment:
#
# 300
#
#
# Finished modified comment:
#
# 301
#
#
# Finished modified comment:
#
# 302
#
#
# Finished modified comment:
#
# 303
#
#
# Finished modified comment:
#
# 304
#
#
# Finished modified comment:
#
# 305
#
#
# Finished modified comment:
#
# 306
#
#
# Finished modified comment:
#
# 307
#
#
# Finished modified comment:
#
# 308
#
#
# Finished modified comment:
#
# 309
#
#
# Finished modified comment:
#
# 310
#
#
# Finished modified comment:
#
# 311
#
#
# Finished modified comment:
#
# 312
#
#
# Finished modified comment:
#
# 313
#
#
# Finished modified comment:
#
# 314
#
#
# Finished modified comment:
#
# 315
#
#
# Finished modified comment:
#
# 316
#
#
# Finished modified comment:
#
# 317
#
#
# Finished modified comment:
#
# 318
#
#
# Finished modified comment:
#
# 319
#
#
# Finished modified comment:
#
# 320
#
#
# Finished modified comment:
#
# 321
#
#
# Finished modified comment:
#
# 322
#
#
# Finished modified comment:
#
# 323
#
#
# Finished modified comment:
#
# 324
#
#
# Finished modified comment:
#
# 325
#
#
# Finished modified comment:
#
# 326
#
#
# Finished modified comment:
#
# 327
#
#
# Finished modified comment:
#
# 328
#
#
# Finished modified comment:
#
# 329
#
#
# Finished modified comment:
#
# 330
#
#
# Finished modified comment:
#
# 331
#
#
# Finished modified comment:
#
# 332
#
#
# Finished modified comment:
#
# 333
#
#
# Finished modified comment:
#
# 334
#
#
# Finished modified comment:
#
# 335
#
#
# Finished modified comment:
#
# 336
#
#
# Finished modified comment:
#
# 337
#
#
# Finished modified comment:
#
# 338
#
#
# Finished modified comment:
#
# 339
#
#
# Finished modified comment:
#
# 340
#
#
# Finished modified comment:
#
# 341
#
#
# Finished modified comment:
#
# 342
#
#
# Finished modified comment:
#
# 343
#
#
# Finished modified comment:
#
# 344
#
#
# Finished modified comment:
#
# 345
#
#
# Finished modified comment:
#
# 346
#
#
# Finished modified comment:
#
# 347
#
#
# Finished modified comment:
#
# 348
#
#
# Finished modified comment:
# 349
#
#
# Finished modified comment:
#
# 350
#
#
# Finished modified comment:
#
# 351
#
#
# Finished modified comment:
#
# 352
#
#
# Finished modified comment:
#
# 353
#
#
# Finished modified comment:
#
# 354
#
#
# Finished modified comment:
#
# 355
#
#
# Finished modified comment:
#
# 356
#
#
# Finished modified comment:
#
# 357
#
#
# Finished modified comment:
#
# 358
#
#
# Finished modified comment:
#
# 359
#
#
# Finished modified comment:
#
# 360
#
#
# Finished modified comment:
#
# 361
#
#
# Finished modified comment:
#
# 362
#
#
# Finished modified comment:
#
# 363
#
#
# Finished modified comment:
#
# 364
#
#
# Finished modified comment:
#
# 365
#
#
# Finished modified comment:
#
# 366
#
#
# Finished modified comment:
#
# 367
#
#
# Finished modified comment:
#
# 368
#
#
# Finished modified comment:
#
# 369
#
#
# Finished modified comment:
#
# 370
#
#
# Finished modified comment:
#
# 371
#
#
# Finished modified comment:
#
# 372
#
#
# Finished modified comment:
#
# 373
#
#
# Finished modified comment:
#
# 374
#
#
# Finished modified comment:
#
# 375
#
#
# Finished modified comment:
#
# 376
#
#
# Finished modified comment:
#
# 377
#
#
# Finished modified comment:
#
# 378
#
#
# Finished modified comment:
#
# 379
#
#
# Finished modified comment:
#
# 380
#
#
# Finished modified comment:
#
# 381
#
#
# Finished modified comment:
#
# 382
#
#
# Finished modified comment:
#
# 383
#
#
# Finished modified comment:
#
# 384
#
#
# Finished modified comment:
#
# 385
#
#
# Finished modified comment:
#
# 386
#
#
# Finished modified comment:
#
# 387
#
#
# Finished modified comment:
#
# 388
#
#
# Finished modified comment:
#
# 389
#
#
# Finished modified comment:
#
# 390
#
#
# Finished modified comment:
#
# 391
#
#
# Finished modified comment:
#
# 392
#
#
# Finished modified comment:
#
# 393
#
#
# Finished modified comment:
#
# 394
#
#
# Finished modified comment:
#
# 395
#
#
# Finished modified comment:
#
# 396
#
#
# Finished modified comment:
#
# 397
#
#
# Finished modified comment:
#
# 398
#
#
# Finished modified comment:
#
# 399
#
#
# Finished modified comment:
#
# 400
#
#
# Finished modified comment:
#
# 401
#
#
# Finished modified comment:
#
# 402
#
#
# Finished modified comment:
#
# 403
#
#
# Finished modified comment:
#
# 404
#
#
# Finished modified comment:
#
# 405
#
#
# Finished modified comment:
#
# 406
#
#
# Finished modified comment:
#
# 407
#
#
# Finished modified comment:
#
# 408
#
#
# Finished modified comment:
#
# 409
#
#
# Finished modified comment:
#
# 410
#
#
# Finished modified comment:
#
# 411
#
#
# Finished modified comment:
#
# 412
#
#
# Finished modified comment:
#
# 413
#
#
# Finished modified comment:
#
# 414
#
#
# Finished modified comment:
#
# 415
#
#
# Finished modified comment:
#
# 416
#
#
# Finished modified comment:
#
# 417
#
#
# Finished modified comment:
#
# 418
#
#
# Finished modified comment:
#
# 419
#
#
# Finished modified comment:
#
# 420
#
#
# Finished modified comment:
#
# 421
#
#
# Finished modified comment:
#
# 422
#
#
# Finished modified comment:
#
# 423
#
#
# Finished modified comment:
#
# 424
#
#
# Finished modified comment:
#
# 425
#
#
# Finished modified comment:
#
# 426
#
#
# Finished modified comment:
#
# 427
#
#
# Finished modified comment:
#
# 428
#
#
# Finished modified comment:
#
# 429
#
#
# Finished modified comment:
#
# 430
#
#
# Finished modified comment:
#
# 431
#
#
# Finished modified comment:
#
# 432
#
#
# Finished modified comment:
#
# 433
#
#
# Finished modified comment:
#
# 434
#
#
# Finished modified comment:
#
# 435
#
#
# Finished modified comment:
#
# 436
#
#
# Finished modified comment:
#
# 437
#
#
# Finished modified comment:
#
# 438
#
#
# Finished modified comment:
#
# 439
#
#
# Finished modified comment:
#
# 440
#
#
# Finished modified comment:
#
# 441
#
#
# Finished modified comment:
#
# 442
#
#
# Finished modified comment:
#
# 443
#
#
# Finished modified comment:
#
# 444
#
#
# Finished modified comment:
#
# 445
#
#
# Finished modified comment:
#
# 446
#
#
# Finished modified comment:
#
# 447
#
#
# Finished modified comment:
#
# 448
#
#
# Finished modified comment:
#
# 449
#
#
# Finished modified comment:
#
# 450
#
#
# Finished modified comment:
#
# 451
#
#
# Finished modified comment:
#
# 452
#
#
# Finished modified comment:
#
# 453
#
#
# Finished modified comment:
#
# 454
#
#
# Finished modified comment:
#
# 455
#
#
# Finished modified comment:
#
# 456
#
#
# Finished modified comment:
#
# 457
#
#
# Finished modified comment:
#
# 458
#
#
# Finished modified comment:
#
# 459
#
#
# Finished modified comment:
#
# 460
#
#
# Finished modified comment:
#
# 461
#
#
# Finished modified comment:
#
# 462
#
#
# Finished modified comment:
#
# 463
#
#
# Finished modified comment:
#
# 464
#
#
# Finished modified comment:
#
# 465
#
#
# Finished modified comment:
#
# 466
#
#
# Finished modified comment:
#
# 467
#
#
# Finished modified comment:
#
# 468
#
#
# Finished modified comment:
#
# 469
#
#
# Finished modified comment:
#
# 470
#
#
# Finished modified comment:
#
# 471
#
#
# Finished modified comment:
#
# 472
#
#
# Finished modified comment:
#
# 473
#
#
# Finished modified comment:
#
# 474
#
#
# Finished modified comment:
#
# 475
#
#
# Finished modified comment:
#
# 476
#
#
# Finished modified comment:
#
# 477
#
#
# Finished modified comment:
#
# 478
#
#
# Finished modified comment:
#
# 479
#
#
# Finished modified comment:
#
# 480
#
#
# Finished modified comment:
#
# 481
#
#
# Finished modified comment:
#
# 482
#
#
# Finished modified comment:
#
# 483
#
#
# Finished modified comment:
#
# 484
#
#
# Finished modified comment:
#
# 485
#
#
# Finished modified comment:
#
# 486
#
#
# Finished modified comment:
#
# 487
#
#
# Finished modified comment:
#
# 488
#
#
# Finished modified comment:
#
# 489
#
#
# Finished modified comment:
#
# 490
#
#
# Finished modified comment:
#
# 491
#
#
# Finished modified comment:
#
# 492
#
#
# Finished modified comment:
#
# 493
#
#
# Finished modified comment:
#
# 494
#
#
# Finished modified comment:
#
# 495
#
#
# Finished modified comment:
#
# 496
#
#
# Finished modified comment:
#
# 497
#
#
# Finished modified comment:
#
# 498
#
#
# Finished modified comment:
#
# 499
#
#
# Finished modified comment:
#
# 500
#
#
# Finished modified comment:
#
# 501
#
#
# Finished modified comment:
#
# 502
#
#
# Finished modified comment:
#
# 503
#
#
# Finished modified comment:
#
# 504
#
#
# Finished modified comment:
#
# 505
#
#
# Finished modified comment:
#
# 506
#
#
# Finished modified comment:
#
# 507
#
#
# Finished modified comment:
#
# 508
#
#
# Finished modified comment:
#
# 509
#
#
# Finished modified comment:
#
# 510
#
#
# Finished modified comment:
#
# 511
#
#
# Finished modified comment:
#
# 512
#
#
# Finished modified comment:
#
# 513
#
#
# Finished modified comment:
#
# 514
#
#
# Finished modified comment:
#
# 515
#
#
# Finished modified comment:
#
# 516
#
#
# Finished modified comment:
#
# 517
#
#
# Finished modified comment:
#
# 518
#
#
# Finished modified comment:
#
# 519
#
#
# Finished modified comment:
#
# 520
#
#
# Finished modified comment:
#
# 521
#
#
# Finished modified comment:
#
# 522
#
#
# Finished modified comment:
#
# 523
#
#
# Finished modified comment:
#
# 524
#
#
# Finished modified comment:
#
# 525
#
#
# Finished modified comment:
#
# 526
#
#
# Finished modified comment:
#
# 527
#
#
# Finished modified comment:
#
# 528
#
#
# Finished modified comment:
#
# 529
#
#
# Finished modified comment:
#
# 530
#
#
# Finished modified comment:
#
# 531
#
#
# Finished modified comment:
#
# 532
#
#
# Finished modified comment:
#
# 533
#
#
# Finished modified comment:
#
# 534
#
#
# Finished modified comment:
#
# 535
#
#
# Finished modified comment:
#
# 536
#
#
# Finished modified comment:
#
# 537
#
#
# Finished modified comment:
#
# 538
#
#
# Finished modified comment:
#
# 539
#
#
# Finished modified comment:
#
# 540
#
#
# Finished modified comment:
#
# 541
#
#
# Finished modified comment:
#
# 542
#
#
# Finished modified comment:
#
# 543
#
#
# Finished modified comment:
#
# 544
#
#
# Finished modified comment:
#
# 545
#
#
# Finished modified comment:
#
# 546
#
#
# Finished modified comment:
#
# 547
#
#
# Finished modified comment:
#
# 548
#
#
# Finished modified comment:
#
# 549
#
#
# Finished modified comment:
#
# 550
#
#
# Finished modified comment:
#
# 551
#
#
# Finished modified comment:
#
# 552
#
#
# Finished modified comment:
#
# 553
#
#
# Finished modified comment:
#
# 554
#
#
# Finished modified comment:
#
# 555
#
#
# Finished modified comment:
#
# 556
#
#
# Finished modified comment:
#
# 557
#
#
# Finished modified comment:
#
# 558
#
#
# Finished modified comment:
#
# 559
#
#
# Finished modified comment:
#
# 560
#
#
# Finished modified comment:
#
# 561
#
#
# Finished modified comment:
#
# 562
#
#
# Finished modified comment:
#
# 563
#
#
# Finished modified comment:
#
# 564
#
#
# Finished modified comment:
#
# 565
#
#
# Finished modified comment:
#
# 566
#
#
# Finished modified comment:
#
# 567
#
#
# Finished modified comment:
#
# 568
#
#
# Finished modified comment:
#
# 569
#
#
# Finished modified comment:
#
# 570
#
#
# Finished modified comment:
#
# 571
#
#
# Finished modified comment:
#
# 572
#
#
# Finished modified comment:
#
# 573
#
#
# Finished modified comment:
#
# 574
#
#
# Finished modified comment:
#
# 575
#
#
# Finished modified comment:
#
# 576
#
#
# Finished modified comment:
#
# 577
#
#
# Finished modified comment:
#
# 578
#
#
# Finished modified comment:
#
# 579
#
#
# Finished modified comment:
#
# 580
#
#
# Finished modified comment:
#
# 581
#
#
# Finished modified comment:
#
# 582
#
#
# Finished modified comment:
#
# 583
#
#
# Finished modified comment:
#
# 584
#
#
# Finished modified comment:
#
# 585
#
#
# Finished modified comment:
#
# 586
#
#
# Finished modified comment:
#
# 587
#
#
# Finished modified comment:
#
# 588
#
#
# Finished modified comment:
#
# 589
#
#
# Finished modified comment:
#
# 590
#
#
# Finished modified comment:
#
# 591
#
#
# Finished modified comment:
#
# 592
#
#
# Finished modified comment:
#
# 593
#
#
# Finished modified comment:
#
# 594
#
#
# Finished modified comment:
#
# 595
#
#
# Finished modified comment:
#
# 596
#
#
# Finished modified comment:
#
# 597
#
#
# Finished modified comment:
#
# 598
#
#
# Finished modified comment:
#
# 599
#
#
# Finished modified comment:
#
# 600
#
#
# Finished modified comment:
#
# 601
#
#
# Finished modified comment:
#
# 602
#
#
# Finished modified comment:
#
# 603
#
#
# Finished modified comment:
#
# 604
#
#
# Finished modified comment:
#
# 605
#
#
# Finished modified comment:
#
# 606
#
#
# Finished modified comment:
#
# 607
#
#
# Finished modified comment:
#
# 608
#
#
# Finished modified comment:
#
# 609
#
#
# Finished modified comment:
#
# 610
#
#
# Finished modified comment:
#
# 611
#
#
# Finished modified comment:
#
# 612
#
#
# Finished modified comment:
#
# 613
#
#
# Finished modified comment:
#
# 614
#
#
# Finished modified comment:
#
# 615
#
#
# Finished modified comment:
#
# 616
#
#
# Finished modified comment:
#
# 617
#
#
# Finished modified comment:
#
# 618
#
#
# Finished modified comment:
#
# 619
#
#
# Finished modified comment:
#
# 620
#
#
# Finished modified comment:
#
# 621
#
#
# Finished modified comment:
#
# 622
#
#
# Finished modified comment:
#
# 623
#
#
# Finished modified comment:
#
# 624
#
#
# Finished modified comment:
#
# 625
#
#
# Finished modified comment:
#
# 626
#
#
# Finished modified comment:
#
# 627
#
#
# Finished modified comment:
#
# 628
#
#
# Finished modified comment:
#
# 629
#
#
# Finished modified comment:
#
# 630
#
#
# Finished modified comment:
#
# 631
#
#
# Finished modified comment:
#
# 632
#
#
# Finished modified comment:
#
# 633
#
#
# Finished modified comment:
#
# 634
#
#
# Finished modified comment:
#
# 635
#
#
# Finished modified comment:
#
# 636
#
#
# Finished modified comment:
#
# 637
#
#
# Finished modified comment:
#
# 638
#
#
# Finished modified comment:
#
# 639
#
#
# Finished modified comment:
#
# 640
#
#
# Finished modified comment:
#
# 641
#
#
# Finished modified comment:
#
# 642
#
#
# Finished modified comment:
#
# 643
#
#
# Finished modified comment:
#
# 644
#
#
# Finished modified comment:
#
# 645
#
#
# Finished modified comment:
#
# 646
#
#
# Finished modified comment:
#
# 647
#
#
# Finished modified comment:
#
# 648
#
#
# Finished modified comment:
#
# 649
#
#
# Finished modified comment:
#
# 650
#
#
# Finished modified comment:
#
# 651
#
#
# Finished modified comment:
#
# 652
#
#
# Finished modified comment:
#
# 653
#
#
# Finished modified comment:
#
# 654
#
#
# Finished modified comment:
#
# 655
#
#
# Finished modified comment:
#
# 656
#
#
# Finished modified comment:
#
# 657
#
#
# Finished modified comment:
#
# 658
#
#
# Finished modified comment:
#
# 659
#
#
# Finished modified comment:
#
# 660
#
#
# Finished modified comment:
#
# 661
#
#
# Finished modified comment:
#
# 662
#
#
# Finished modified comment:
#
# 663
#
#
# Finished modified comment:
#
# 664
#
#
# Finished modified comment:
#
# 665
#
#
# Finished modified comment:
#
# 666
#
#
# Finished modified comment:
#
# 667
#
#
# Finished modified comment:
#
# 668
#
#
# Finished modified comment:
#
# 669
#
#
# Finished modified comment:
#
# 670
#
#
# Finished modified comment:
#
# 671
#
#
# Finished modified comment:
#
# 672
#
#
# Finished modified comment:
#
# 673
#
#
# Finished modified comment:
#
# 674
#
#
# Finished modified comment:
#
# 675
#
#
# Finished modified comment:
#
# 676
#
#
# Finished modified comment:
#
# 677
#
#
# Finished modified comment:
#
# 678
#
#
# Finished modified comment:
#
# 679
#
#
# Finished modified comment:
#
# 680
#
#
# Finished modified comment:
#
# 681
#
#
# Finished modified comment:
#
# 682
#
#
# Finished modified comment:
#
# 683
#
#
# Finished modified comment:
#
# 684
#
#
# Finished modified comment:
#
# 685
#
#
# Finished modified comment:
#
# 686
#
#
# Finished modified comment:
#
# 687
#
#
# Finished modified comment:
#
# 688
#
#
# Finished modified comment:
#
# 689
#
#
# Finished modified comment:
#
# 690
#
#
# Finished modified comment:
#
# 691
#
#
# Finished modified comment:
#
# 692
#
#
# Finished modified comment:
#
# 693
# Finished modified comment:
#
# 694
#
#
# Finished modified comment:
#
# 695
#
#
# Finished modified comment:
#
# 696
#
#
# Finished modified comment:
#
# 697
#
#
# Finished modified comment:
#
# 698
#
#
# Finished modified comment:
#
# 699
#
#
# Finished modified comment:
#
# 700
#
#
# Finished modified comment:
#
# 701
#
#
# Finished modified comment:
#
# 702
#
#
# Finished modified comment:
#
# 703
#
#
# Finished modified comment:
#
# 704
#
#
# Finished modified comment:
#
# 705
#
#
# Finished modified comment:
#
# 706
#
#
# Finished modified comment:
#
# 707
#
#
# Finished modified comment:
#
# 708
#
#
# Finished modified comment:
#
# 709
#
#
# Finished modified comment:
#
# 710
#
#
# Finished modified comment:
#
# 711
#
#
# Finished modified comment:
#
# 712
#
#
# Finished modified comment:
#
# 713
#
#
# Finished modified comment:
#
# 714
#
#
# Finished modified comment:
#
# 715
#
#
# Finished modified comment:
#
# 716
#
#
# Finished modified comment:
#
# 717
#
#
# Finished modified comment:
#
# 718
#
#
# Finished modified comment:
#
# 719
#
#
# Finished modified comment:
#
# 720
#
#
# Finished modified comment:
#
# 721
#
#
# Finished modified comment:
#
# 722
#
#
# Finished modified comment:
#
# 723
#
#
# Finished modified comment:
#
# 724
#
#
# Finished modified comment:
#
# 725
#
#
# Finished modified comment:
#
# 726
#
#
# Finished modified comment:
#
# 727
#
#
# Finished modified comment:
#
# 728
#
#
# Finished modified comment:
#
# 729
#
#
# Finished modified comment:
#
# 730
#
#
# Finished modified comment:
#
# 731
#
#
# Finished modified comment:
#
# 732
#
#
# Finished modified comment:
#
# 733
#
#
# Finished modified comment:
#
# 734
#
#
# Finished modified comment:
#
# 735
#
#
# Finished modified comment:
#
# 736
#
#
# Finished modified comment:
#
# 737
#
#
# Finished modified comment:
#
# 738
#
#
# Finished modified comment:
#
# 739
#
#
# Finished modified comment:
#
# 740
#
#
# Finished modified comment:
#
# 741
#
#
# Finished modified comment:
#
# 742
#
#
# Finished modified comment:
#
# 743
#
#
# Finished modified comment:
#
# 744
#
#
# Finished modified comment:
#
# 745
#
#
# Finished modified comment:
#
# 746
#
#
# Finished modified comment:
#
# 747
#
#
# Finished modified comment:
#
# 748
#
#
# Finished modified comment:
#
# 749
#
#
# Finished modified comment:
#
# 750
#
#
# Finished modified comment:
#
# 751
#
#
# Finished modified comment:
#
# 752
#
#
# Finished modified comment:
#
# 753
#
#
# Finished modified comment:
#
# 754
#
#
# Finished modified comment:
#
# 755
#
#
# Finished modified comment:
#
# 756
#
#
# Finished modified comment:
#
# 757
#
#
# Finished modified comment:
#
# 758
#
#
# Finished modified comment:
#
# 759
#
#
# Finished modified comment:
#
# 760
#
#
# Finished modified comment:
#
# 761
#
#
# Finished modified comment:
#
# 762
#
#
# Finished modified comment:
#
# 763
#
#
# Finished modified comment:
#
# 764
#
#
# Finished modified comment:
#
# 765
#
#
# Finished modified comment:
#
# 766
#
#
# Finished modified comment:
#
# 767
#
#
# Finished modified comment:
#
# 768
#
#
# Finished modified comment:
#
# 769
#
#
# Finished modified comment:
#
# 770
#
#
# Finished modified comment:
#
# 771
#
#
# Finished modified comment:
#
# 772
#
#
# Finished modified comment:
#
# 773
#
#
# Finished modified comment:
#
# 774
#
#
# Finished modified comment:
#
# 775
#
#
# Finished modified comment:
#
# 776
#
#
# Finished modified comment:
#
# 777
#
#
# Finished modified comment:
#
# 778
#
#
# Finished modified comment:
#
# 779
#
#
# Finished modified comment:
#
# 780
#
#
# Finished modified comment:
#
# 781
#
#
# Finished modified comment:
#
# 782
#
#
# Finished modified comment:
#
# 783
#
#
# Finished modified comment:
#
# 784
#
#
# Finished modified comment:
#
# 785
#
#
# Finished modified comment:
#
# 786
#
#
# Finished modified comment:
#
# 787
#
#
# Finished modified comment:
#
# 788
#
#
# Finished modified comment:
#
# 789
#
#
# Finished modified comment:
#
# 790
#
#
# Finished modified comment:
#
# 791
#
#
# Finished modified comment:
#
# 792
#
#
# Finished modified comment:
#
# 793
#
#
# Finished modified comment:
#
# 794
#
#
# Finished modified comment:
#
# 795
#
#
# Finished modified comment:
#
# 796
#
#
# Finished modified comment:
#
# 797
#
#
# Finished modified comment:
#
# 798
#
#
# Finished modified comment:
#
# 799
#
#
# Finished modified comment:
#
# 800
#
#
# Finished modified comment:
#
# 801
#
#
# Finished modified comment:
#
# 802
#
#
# Finished modified comment:
#
# 803
#
#
# Finished modified comment:
#
# 804
#
#
# Finished modified comment:
#
# 805
#
#
# Finished modified comment:
#
# 806
#
#
# Finished modified comment:
#
# 807
#
#
# Finished modified comment:
#
# 808
#
#
# Finished modified comment:
#
# 809
#
#
# Finished modified comment:
#
# 810
#
#
# Finished modified comment:
#
# 811
#
#
# Finished modified comment:
#
# 812
#
#
# Finished modified comment:
#
# 813
#
#
# Finished modified comment:
#
# 814
#
#
# Finished modified comment:
#
# 815
#
#
# Finished modified comment:
#
# 816
#
#
# Finished modified comment:
#
# 817
#
#
# Finished modified comment:
#
# 818
#
#
# Finished modified comment:
#
# 819
#
#
# Finished modified comment:
#
# 820
#
#
# Finished modified comment:
#
# 821
#
#
# Finished modified comment:
#
# 822
#
#
# Finished modified comment:
#
# 823
#
#
# Finished modified comment:
#
# 824
#
#
# Finished modified comment:
#
# 825
#
#
# Finished modified comment:
#
# 826
#
#
# Finished modified comment:
#
# 827
#
#
# Finished modified comment:
#
# 828
#
#
# Finished modified comment:
#
# 829
#
#
# Finished modified comment:
#
# 830
#
#
# Finished modified comment:
#
# 831
#
#
# Finished modified comment:
#
# 832
#
#
# Finished modified comment:
#
# 833
#
#
# Finished modified comment:
#
# 834
#
#
# Finished modified comment:
#
# 835
#
#
# Finished modified comment:
#
# 836
#
#
# Finished modified comment:
#
# 837
#
#
# Finished modified comment:
#
# 838
#
#
# Finished modified comment:
#
# 839
#
#
# Finished modified comment:
#
# 840
#
#
# Finished modified comment:
#
# 841
#
#
# Finished modified comment:
#
# 842
#
#
# Finished modified comment:
#
# 843
#
#
# Finished modified comment:
#
# 844
#
#
# Finished modified comment:
#
# 845
#
#
# Finished modified comment:
#
# 846
#
#
# Finished modified comment:
#
# 847
#
#
# Finished modified comment:
#
# 848
#
#
# Finished modified comment:
#
# 849
#
#
# Finished modified comment:
#
# 850
#
#
# Finished modified comment:
#
# 851
#
#
# Finished modified comment:
#
# 852
#
#
# Finished modified comment:
#
# 853
#
#
# Finished modified comment:
#
# 854
#
#
# Finished modified comment:
#
# 855
#
#
# Finished modified comment:
#
# 856
#
#
# Finished modified comment:
#
# 857
#
#
# Finished modified comment:
#
# 858
#
#
# Finished modified comment:
#
# 859
#
#
# Finished modified comment:
#
# 860
#
#
# Finished modified comment:
#
# 861
#
#
# Finished modified comment:
#
# 862
#
#
# Finished modified comment:
#
# 863
#
#
# Finished modified comment:
#
# 864
#
#
# Finished modified comment:
#
# 865
#
#
# Finished modified comment:
#
# 866
#
#
# Finished modified comment:
#
# 867
#
#
# Finished modified comment:
#
# 868
#
#
# Finished modified comment:
#
# 869
#
#
# Finished modified comment:
#
# 870
#
#
# Finished modified comment:
#
# 871
#
#
# Finished modified comment:
#
# 872
#
#
# Finished modified comment:
#
# 873
#
#
# Finished modified comment:
#
# 874
#
#
# Finished modified comment:
#
# 875
#
#
# Finished modified comment:
#
# 876
#
#
# Finished modified comment:
#
# 877
#
#
# Finished modified comment:
#
# 878
#
#
# Finished modified comment:
#
# 879
#
#
# Finished modified comment:
#
# 880
#
#
# Finished modified comment:
#
# 881
#
#
# Finished modified comment:
#
# 882
#
#
# Finished modified comment:
#
# 883
#
#
# Finished modified comment:
#
# 884
#
#
# Finished modified comment:
#
# 885
#
#
# Finished modified comment:
#
# 886
#
#
# Finished modified comment:
#
# 887
#
#
# Finished modified comment:
#
# 888
#
#
# Finished modified comment:
#
# 889
#
#
# Finished modified comment:
#
# 890
#
#
# Finished modified comment:
#
# 891
#
#
# Finished modified comment:
#
# 892
#
#
# Finished modified comment:
#
# 893
#
#
# Finished modified comment:
#
# 894
#
#
# Finished modified comment:
#
# 895
#
#
# Finished modified comment:
#
# 896
#
#
# Finished modified comment:
#
# 897
#
#
# Finished modified comment:
#
# 898
#
#
# Finished modified comment:
#
# 899
#
#
# Finished modified comment:
#
# 900
#
#
# Finished modified comment:
#
# 901
#
#
# Finished modified comment:
#
# 902
#
#
# Finished modified comment:
#
# 903
#
#
# Finished modified comment:
#
# 904
#
#
# Finished modified comment:
#
# 905
#
#
# Finished modified comment:
#
# 906
#
#
# Finished modified comment:
#
# 907
#
#
# Finished modified comment:
#
# 908
#
#
# Finished modified comment:
#
# 909
#
#
# Finished modified comment:
#
# 910
#
#
# Finished modified comment:
#
# 911
#
#
# Finished modified comment:
#
# 912
#
#
# Finished modified comment:
#
# 913
#
#
# Finished modified comment:
#
# 914
#
#
# Finished modified comment:
#
# 915
#
#
# Finished modified comment:
#
# 916
#
#
# Finished modified comment:
#
# 917
#
#
# Finished modified comment:
#
# 918
#
#
# Finished modified comment:
#
# 919
#
#
# Finished modified comment:
#
# 920
#
#
# Finished modified comment:
#
# 921
#
#
# Finished modified comment:
#
# 922
#
#
# Finished modified comment:
#
# 923
#
#
# Finished modified comment:
#
# 924
#
#
# Finished modified comment:
#
# 925
#
#
# Finished modified comment:
#
# 926
#
#
# Finished modified comment:
#
# 927
#
#
# Finished modified comment:
#
# 928
#
#
# Finished modified comment:
#
# 929
#
#
# Finished modified comment:
#
# 930
#
#
# Finished modified comment:
#
# 931
#
#
# Finished modified comment:
#
# 932
#
#
# Finished modified comment:
#
# 933
#
#
# Finished modified comment:
#
# 934
#
#
# Finished modified comment:
#
# 935
#
#
# Finished modified comment:
#
# 936
#
#
# Finished modified comment:
#
# 937
#
#
# Finished modified comment:
#
# 938
#
#
# Finished modified comment:
#
# 939
#
#
# Finished modified comment:
#
# 940
#
#
# Finished modified comment:
#
# 941
#
#
# Finished modified comment:
#
# 942
#
#
# Finished modified comment:
#
# 943
#
#
# Finished modified comment:
#
# 944
#
#
# Finished modified comment:
#
# 945
#
#
# Finished modified comment:
#
# 946
#
#
# Finished modified comment:
#
# 947
#
#
# Finished modified comment:
#
# 948
#
#
# Finished modified comment:
#
# 949
#
#
# Finished modified comment:
#
# 950
#
#
# Finished modified comment:
#
# 951
#
#
# Finished modified comment:
#
# 952
#
#
# Finished modified comment:
#
# 953
#
#
# Finished modified comment:
#
# 954
#
#
# Finished modified comment:
#
# 955
#
#
# Finished modified comment:
#
# 956
#
#
# Finished modified comment:
#
# 957
#
#
# Finished modified comment:
#
# 958
#
#
# Finished modified comment:
#
# 959
#
#
# Finished modified comment:
#
# 960
#
#
# Finished modified comment:
#
# 961
#
#
# Finished modified comment:
#
# 962
#
#
# Finished modified comment:
#
# 963
#
#
# Finished modified comment:
#
# 964
#
#
# Finished modified comment:
#
# 965
#
#
# Finished modified comment:
#
# 966
#
#
# Finished modified comment:
#
# 967
#
#
# Finished modified comment:
#
# 968
#
#
# Finished modified comment:
#
# 969
#
#
# Finished modified comment:
#
# 970
#
#
# Finished modified comment:
#
# 971
#
#
# Finished modified comment:
#
# 972
#
#
# Finished modified comment:
#
# 973
#
#
# Finished modified comment:
#
# 974
#
#
# Finished modified comment:
#
# 975
#
#
# Finished modified comment:
#
# 976
#
#
# Finished modified comment:
#
# 977
#
#
# Finished modified comment:
#
# 978
#
#
# Finished modified comment:
#
# 979
#
#
# Finished modified comment:
#
# 980
#
#
# Finished modified comment:
#
# 981
#
#
# Finished modified comment:
#
# 982
#
#
# Finished modified comment:
#
# 983
#
#
# Finished modified comment:
#
# 984
#
#
# Finished modified comment:
#
# 985
#
#
# Finished modified comment:
#
# 986
#
#
# Finished modified comment:
#
# 987
#
#
# Finished modified comment:
#
# 988
#
#
# Finished modified comment:
#
# 989
#
#
# Finished modified comment:
#
# 990
#
#
# Finished modified comment:
#
# 991
#
#
# Finished modified comment:
#
# 992
#
#
# Finished modified comment:
#
# 993
#
#
# Finished modified comment:
#
# 994
#
#
# Finished modified comment:
# 995
#
#
# Finished modified comment:
#
# 996
#
#
# Finished modified comment:
#
# 997
#
#
# Finished modified comment:
#
# 998
#
#
# Finished modified comment:
#
# 999
#
#
# Finished modified comment:
#
# 1000
#
#
# Finished modified comment:
#
# 1001
#
#
# Finished modified comment:
#
# 1002
#
#
# Finished modified comment:
#
# 1003
#
#
# Finished modified comment:
#
# 1004
#
#
# Finished modified comment:
#
# 1005
#
#
# Finished modified comment:
#
# 1006
#
#
# Finished modified comment:
#
# 1007
#
#
# Finished modified comment:
#
# 1008
#
#
# Finished modified comment:
#
# 1009
#
#
# Finished modified comment:
#
# 1010
#
#
# Finished modified comment:
#
# 1011
#
#
# Finished modified comment:
#
# 1012
#
#
# Finished modified comment:
#
# 1013
#
#
# Finished modified comment:
#
# 1014
#
#
# Finished modified comment:
#
# 1015
#
#
# Finished modified comment:
#
# 1016
#
#
# Finished modified comment:
#
# 1017
#
#
# Finished modified comment:
#
# 1018
#
#
# Finished modified comment:
#
# 1019
#
#
# Finished modified comment:
#
# 1020
#
#
# Finished modified comment:
#
# 1021
#
#
# Finished modified comment:
#
# 1022
#
#
# Finished modified comment:
#
# 1023
#
#
# Finished modified comment:
#
# 1024
#
#
# Finished modified comment:
#
# 1025
#
#
# Finished modified comment:
#
# 1026
#
#
# Finished modified comment:
#
# 1027
#
#
# Finished modified comment:
#
# 1028
#
#
# Finished modified comment:
#
# 1029
#
#
# Finished modified comment:
#
# 1030
#
#
# Finished modified comment:
#
# 1031
#
#
# Finished modified comment:
#
# 1032
#
#
# Finished modified comment:
#
# 1033
#
#
# Finished modified comment:
#
# 1034
#
#
# Finished modified comment:
#
# 1035
#
#
# Finished modified comment:
#
# 1036
#
#
# Finished modified comment:
#
# 1037
#
#
# Finished modified comment:
#
# 1038
#
#
# Finished modified comment:
#
# 1039
#
#
# Finished modified comment:
#
# 1040
#
#
# Finished modified comment:
#
# 1041
#
#
# Finished modified comment:
#
# 1042
#
#
# Finished modified comment:
#
# 1043
#
#
# Finished modified comment:
#
# 1044
#
#
# Finished modified comment:
#
# 1045
#
#
# Finished modified comment:
#
# 1046
#
#
# Finished modified comment:
#
# 1047
#
#
# Finished modified comment:
#
# 1048
#
#
# Finished modified comment:
#
# 1049
#
#
# Finished modified comment:
#
# 0.5703444480895996
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-f183c5d4d6cd> in <module>
#      63 #Save modified comment into file
#      64 keep_col = ['comment','code','non-information']
# ---> 65 new_f = dataframe[keep_col]
#      66 new_f.to_csv("csv/trimedComments.csv", index=False)
#      67
#
# c:\users\benit\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# c:\users\benit\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1551
# -> 1552         self._validate_read_indexer(
#    1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#
# c:\users\benit\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1644             if not (self.name == "loc" and not raise_missing):
#    1645                 not_found = list(set(key) - set(ax))
# -> 1646                 raise KeyError(f"{not_found} not in index")
#    1647
#    1648             # we skip the warning on Categorical/Interval
#
# KeyError: "['code'] not in index"
